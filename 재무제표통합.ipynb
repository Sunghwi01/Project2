# %%
import pandas as pd

# %%
연결 = pd.read_csv('./KOSDAQ/의영이형이 재촉하는 그것.csv', encoding='CP949')
개별 = pd.read_csv('./KOSDAQ/개별재무제표.csv', encoding='CP949')

# %%
df =개별.columns.tolist()
df
# Out:
# ['회사명',
#  '거래소코드',
#  '회계년도',
#  '상장일',
#  '상장폐지일',
#  '산업명',
#  '소속코드',
#  '[제조]매출액증가율(IFRS)',
#  '[제조]총자본증가율(IFRS)',
#  '[제조]자기자본증가율(IFRS)',
#  '[제조]순이익증가율(IFRS)',
#  '[제조]유형자산증가율(IFRS)',
#  '[제조]비유동자산증가율(IFRS)',
#  '[제조]유동자산증가율(IFRS)',
#  '[제조]재고자산증가율(IFRS)',
#  '[제조]매출액총이익률(IFRS)',
#  '[제조]매출액순이익률(IFRS)',
#  '[제조]총자본사업이익률(IFRS)',
#  '[제조]총자본순이익률(IFRS)',
#  '[제조]자기자본순이익률(IFRS)',
#  '[제조]1주당순이익(IFRS)',
#  '[제조]1주당매출액(IFRS)',
#  '[제조]총자본회전률(IFRS)',
#  '[제조]자기자본회전률(IFRS)',
#  '[제조]비유동자산회전률(IFRS)',
#  '[제조]재고자산회전률(IFRS)',
#  '[제조]매출채권회전률(IFRS)',
#  '[제조]매입채무회전률(IFRS)',
#  '[제조]매입채무회전기간(IFRS)',
#  '[제조]재고자산회전기간(IFRS)',
#  '[제조]매출채권회전기간(IFRS)',
#  '[제조]1회전기간(IFRS)',
#  '[제조]운전자본회전률(IFRS)',
#  '[제조]순운전자본회전률(IFRS)',
#  '[제조]유형자산회전율(IFRS)',
#  '[제조]유동자산회전률(IFRS)',
#  '[제조]당좌자산회전률(IFRS)',
#  '[제조]유동비율(IFRS)',
#  '[제조]당좌비율(IFRS)',
#  '[제조]현금비율(IFRS)',
#  '[제조]순운전자본비율(IFRS)',
#  '[제조]부채비율(IFRS)',
#  '[제조]자기자본배율(IFRS)',
#  '[제조]이자보상배율(이자비용)(IFRS)',
#  '[제조]비유동비율(IFRS)',
# ...

# %%
연결.columns.tolist()
# Out:
# ['회사명',
#  '거래소코드',
#  '회계년도',
#  '상장일',
#  '상장폐지일',
#  '산업명',
#  '소속코드',
#  '[제조]매출액증가율(IFRS연결)',
#  '[제조]유형자산증가율(IFRS연결)',
#  '[제조]비유동자산증가율(IFRS연결)',
#  '[제조]총자본증가율(IFRS연결)',
#  '[제조]자기자본증가율(IFRS연결)',
#  '[제조]유동자산증가율(IFRS연결)',
#  '[제조]순이익증가율(IFRS연결)',
#  '[제조]재고자산증가율(IFRS연결)',
#  '[제조]매출액총이익률(IFRS연결)',
#  '[제조]매출액순이익률(IFRS연결)',
#  '[제조]총자본사업이익률(IFRS연결)',
#  '[제조]총자본순이익률(IFRS연결)',
#  '[제조]자기자본순이익률(IFRS연결)',
#  '[제조]1주당순이익(IFRS연결)',
#  '[제조]1주당매출액(IFRS연결)',
#  '[제조]총자본회전률(IFRS연결)',
#  '[제조]자기자본회전률(IFRS연결)',
#  '[제조]비유동자산회전률(IFRS연결)',
#  '[제조]재고자산회전률(IFRS연결)',
#  '[제조]매출채권회전률(IFRS연결)',
#  '[제조]매입채무회전률(IFRS연결)',
#  '[제조]매입채무회전기간(IFRS연결)',
#  '[제조]재고자산회전기간(IFRS연결)',
#  '[제조]매출채권회전기간(IFRS연결)',
#  '[제조]1회전기간(IFRS연결)',
#  '[제조]운전자본회전률(IFRS연결)',
#  '[제조]순운전자본회전률(IFRS연결)',
#  '[제조]유동자산회전률(IFRS연결)',
#  '[제조]당좌자산회전률(IFRS연결)',
#  '[제조]유동비율(IFRS연결)',
#  '[제조]당좌비율(IFRS연결)',
#  '[제조]현금비율(IFRS연결)',
#  '[제조]부채비율(IFRS연결)',
#  '[제조]순운전자본비율(IFRS연결)',
#  '[제조]자기자본배율(IFRS연결)',
#  '[제조]비유동비율(IFRS연결)',
# ...

# %%
연결.columns = ['회사명',
 '거래소코드',
 '회계년도',
 '상장일',
 '상장폐지일',
 '산업명',
 '소속코드',
 '[제조]매출액증가율',
 '[제조]유형자산증가율',
 '[제조]비유동자산증가율',
 '[제조]총자본증가율',
 '[제조]자기자본증가율',
 '[제조]유동자산증가율',
 '[제조]순이익증가율',
 '[제조]재고자산증가율',
 '[제조]매출액총이익률',
 '[제조]매출액순이익률',
 '[제조]총자본사업이익률',
 '[제조]총자본순이익률',
 '[제조]자기자본순이익률',
 '[제조]1주당순이익',
 '[제조]1주당매출액',
 '[제조]총자본회전률',
 '[제조]자기자본회전률',
 '[제조]비유동자산회전률',
 '[제조]재고자산회전률',
 '[제조]매출채권회전률',
 '[제조]매입채무회전률',
 '[제조]매입채무회전기간',
 '[제조]재고자산회전기간',
 '[제조]매출채권회전기간',
 '[제조]1회전기간',
 '[제조]운전자본회전률',
 '[제조]순운전자본회전률',
 '[제조]유동자산회전률',
 '[제조]당좌자산회전률',
 '[제조]유동비율',
 '[제조]당좌비율',
 '[제조]현금비율',
 '[제조]부채비율',
 '[제조]순운전자본비율',
 '[제조]자기자본배율',
 '[제조]비유동비율',
 '[제조]유동자산구성비율',
 '[제조]자기자본구성비율',
 '[제조]부가가치',
 '[제조]총자본투자효율',
 '[제조]설비투자효율',
 '[제조]기계투자효율',
 '[제조]부가가치율',
 '[제조]노동소득분배율',
 '[제조]자본분배율',
 '[제조]이윤분배율',
 '[제조]유형자산회전율',
 '[제조]이자보상배율(이자비용)']

# %%
개별.columns = ['회사명',
 '거래소코드',
 '회계년도',
 '상장일',
 '상장폐지일',
 '산업명',
 '소속코드',
 '[제조]매출액증가율',
 '[제조]유형자산증가율',
 '[제조]비유동자산증가율',
 '[제조]총자본증가율',
 '[제조]자기자본증가율',
 '[제조]유동자산증가율',
 '[제조]순이익증가율',
 '[제조]재고자산증가율',
 '[제조]매출액총이익률',
 '[제조]매출액순이익률',
 '[제조]총자본사업이익률',
 '[제조]총자본순이익률',
 '[제조]자기자본순이익률',
 '[제조]1주당순이익',
 '[제조]1주당매출액',
 '[제조]총자본회전률',
 '[제조]자기자본회전률',
 '[제조]비유동자산회전률',
 '[제조]재고자산회전률',
 '[제조]매출채권회전률',
 '[제조]매입채무회전률',
 '[제조]매입채무회전기간',
 '[제조]재고자산회전기간',
 '[제조]매출채권회전기간',
 '[제조]1회전기간',
 '[제조]운전자본회전률',
 '[제조]순운전자본회전률',
 '[제조]유동자산회전률',
 '[제조]당좌자산회전률',
 '[제조]유동비율',
 '[제조]당좌비율',
 '[제조]현금비율',
 '[제조]부채비율',
 '[제조]순운전자본비율',
 '[제조]자기자본배율',
 '[제조]비유동비율',
 '[제조]유동자산구성비율',
 '[제조]자기자본구성비율',
 '[제조]부가가치',
 '[제조]총자본투자효율',
 '[제조]설비투자효율',
 '[제조]기계투자효율',
 '[제조]부가가치율',
 '[제조]노동소득분배율',
 '[제조]자본분배율',
 '[제조]이윤분배율',
 '[제조]유형자산회전율',
 '[제조]이자보상배율(이자비용)']

# %%
개별.columns = ['회사명',
 '거래소코드',
 '회계년도',
 '상장일',
 '상장폐지일',
 '산업명',
 '소속코드',
 '[제조]매출액증가율',
 '[제조]총자본증가율',
 '[제조]자기자본증가율',
 '[제조]순이익증가율',
 '[제조]유형자산증가율',
 '[제조]비유동자산증가율',
 '[제조]유동자산증가율',
 '[제조]재고자산증가율',
 '[제조]매출액총이익률',
 '[제조]매출액순이익률',
 '[제조]총자본사업이익률',
 '[제조]총자본순이익률',
 '[제조]자기자본순이익률',
 '[제조]1주당순이익',
 '[제조]1주당매출액',
 '[제조]총자본회전률',
 '[제조]자기자본회전률',
 '[제조]비유동자산회전률',
 '[제조]재고자산회전률',
 '[제조]매출채권회전률',
 '[제조]매입채무회전률',
 '[제조]매입채무회전기간',
 '[제조]재고자산회전기간',
 '[제조]매출채권회전기간',
 '[제조]1회전기간',
 '[제조]운전자본회전률',
 '[제조]순운전자본회전률',
 '[제조]유형자산회전율',
 '[제조]유동자산회전률',
 '[제조]당좌자산회전률',
 '[제조]유동비율',
 '[제조]당좌비율',
 '[제조]현금비율',
 '[제조]순운전자본비율',
 '[제조]부채비율',
 '[제조]자기자본배율',
 '[제조]이자보상배율(이자비용)',
 '[제조]비유동비율',
 '[제조]유동자산구성비율',
 '[제조]자기자본구성비율',
 '[제조]부가가치',
 '[제조]총자본투자효율',
 '[제조]설비투자효율',
 '[제조]기계투자효율',
 '[제조]부가가치율',
 '[제조]노동소득분배율',
 '[제조]자본분배율',
 '[제조]이윤분배율']

# %%
개별 = 개별[['회사명',
 '거래소코드',
 '회계년도',
 '상장일',
 '상장폐지일',
 '산업명',
 '소속코드',
 '[제조]매출액증가율',
 '[제조]총자본증가율',
 '[제조]자기자본증가율',
 '[제조]순이익증가율',
 '[제조]유형자산증가율',
 '[제조]비유동자산증가율',
 '[제조]유동자산증가율',
 '[제조]재고자산증가율',
 '[제조]매출액총이익률',
 '[제조]매출액순이익률',
 '[제조]총자본사업이익률',
 '[제조]총자본순이익률',
 '[제조]자기자본순이익률',
 '[제조]1주당순이익',
 '[제조]1주당매출액',
 '[제조]총자본회전률',
 '[제조]자기자본회전률',
 '[제조]비유동자산회전률',
 '[제조]재고자산회전률',
 '[제조]매출채권회전률',
 '[제조]매입채무회전률',
 '[제조]매입채무회전기간',
 '[제조]재고자산회전기간',
 '[제조]매출채권회전기간',
 '[제조]1회전기간',
 '[제조]운전자본회전률',
 '[제조]순운전자본회전률',
 '[제조]유형자산회전율',
 '[제조]유동자산회전률',
 '[제조]당좌자산회전률',
 '[제조]유동비율',
 '[제조]당좌비율',
 '[제조]현금비율',
 '[제조]순운전자본비율',
 '[제조]부채비율',
 '[제조]자기자본배율',
 '[제조]이자보상배율(이자비용)',
 '[제조]비유동비율',
 '[제조]유동자산구성비율',
 '[제조]자기자본구성비율',
 '[제조]부가가치',
 '[제조]총자본투자효율',
 '[제조]설비투자효율',
 '[제조]기계투자효율',
 '[제조]부가가치율',
 '[제조]노동소득분배율',
 '[제조]자본분배율',
 '[제조]이윤분배율']]

# %%
# Out:
#             회사명  거래소코드     회계년도         상장일 상장폐지일            산업명  소속코드  \
# 0      (주)CMG제약  58820  2011/12  2001/08/31   NaN        의약품 제조업     5
# 1      (주)CMG제약  58820  2012/12  2001/08/31   NaN        의약품 제조업     5
# 2      (주)CMG제약  58820  2013/12  2001/08/31   NaN        의약품 제조업     5
# 3      (주)CMG제약  58820  2014/12  2001/08/31   NaN        의약품 제조업     5
# 4      (주)CMG제약  58820  2015/12  2001/08/31   NaN        의약품 제조업     5
# ...         ...    ...      ...         ...   ...            ...   ...
# 11228   흥구석유(주)  24060  2016/12  1994/12/07   NaN      기타 전문 도매업     5
# 11229   흥구석유(주)  24060  2017/12  1994/12/07   NaN      기타 전문 도매업     5
# 11230   흥구석유(주)  24060  2018/12  1994/12/07   NaN      기타 전문 도매업     5
# 11231   흥구석유(주)  24060  2019/12  1994/12/07   NaN      기타 전문 도매업     5
# 11232   흥구석유(주)  24060  2020/12  1994/12/07   NaN      기타 전문 도매업     5
#
#        [제조]매출액증가율  [제조]총자본증가율  [제조]자기자본증가율  ...  [제조]유동자산구성비율  [제조]자기자본구성비율  \
# ...

# %%
연결
# Out:
#             회사명  거래소코드     회계년도         상장일 상장폐지일                 산업명  소속코드  \
# 0      (주)CMG제약  58820  2011/12  2001/08/31   NaN    의료용 물질 및 의약품 제조업     5
# 1      (주)CMG제약  58820  2012/12  2001/08/31   NaN    의료용 물질 및 의약품 제조업     5
# 2      (주)CMG제약  58820  2013/12  2001/08/31   NaN    의료용 물질 및 의약품 제조업     5
# 3      (주)CMG제약  58820  2014/12  2001/08/31   NaN    의료용 물질 및 의약품 제조업     5
# 4      (주)CMG제약  58820  2015/12  2001/08/31   NaN    의료용 물질 및 의약품 제조업     5
# ...         ...    ...      ...         ...   ...                 ...   ...
# 11228   흥구석유(주)  24060  2016/12  1994/12/07   NaN         도매 및 상품 중개업     5
# 11229   흥구석유(주)  24060  2017/12  1994/12/07   NaN         도매 및 상품 중개업     5
# 11230   흥구석유(주)  24060  2018/12  1994/12/07   NaN         도매 및 상품 중개업     5
# 11231   흥구석유(주)  24060  2019/12  1994/12/07   NaN         도매 및 상품 중개업     5
# 11232   흥구석유(주)  24060  2020/12  1994/12/07   NaN         도매 및 상품 중개업     5
#
# ...

# %%
all = pd.merge(연결,개별,on=['회사명','거래소코드',
 '회계년도',
 '상장일',
 '상장폐지일',
 '산업명',
 '소속코드',
 '[제조]매출액증가율',
 '[제조]총자본증가율',
 '[제조]자기자본증가율',
 '[제조]순이익증가율',
 '[제조]유형자산증가율',
 '[제조]비유동자산증가율',
 '[제조]유동자산증가율',
 '[제조]재고자산증가율',
 '[제조]매출액총이익률',
 '[제조]매출액순이익률',
 '[제조]총자본사업이익률',
 '[제조]총자본순이익률',
 '[제조]자기자본순이익률',
 '[제조]1주당순이익',
 '[제조]1주당매출액',
 '[제조]총자본회전률',
 '[제조]자기자본회전률',
 '[제조]비유동자산회전률',
 '[제조]재고자산회전률',
 '[제조]매출채권회전률',
 '[제조]매입채무회전률',
 '[제조]매입채무회전기간',
 '[제조]재고자산회전기간',
 '[제조]매출채권회전기간',
 '[제조]1회전기간',
 '[제조]운전자본회전률',
 '[제조]순운전자본회전률',
 '[제조]유형자산회전율',
 '[제조]유동자산회전률',
 '[제조]당좌자산회전률',
 '[제조]유동비율',
 '[제조]당좌비율',
 '[제조]현금비율',
 '[제조]순운전자본비율',
 '[제조]부채비율',
 '[제조]자기자본배율',
 '[제조]이자보상배율(이자비용)',
 '[제조]비유동비율',
 '[제조]유동자산구성비율',
 '[제조]자기자본구성비율',
 '[제조]부가가치',
 '[제조]총자본투자효율',
 '[제조]설비투자효율',
 '[제조]기계투자효율',
 '[제조]부가가치율',
 '[제조]노동소득분배율',
 '[제조]자본분배율',
 '[제조]이윤분배율'], how='outer')

# %%
all.head(60)
# Out:
#            회사명   거래소코드     회계년도         상장일 상장폐지일                       산업명  \
# 0     (주)CMG제약   58820  2011/12  2001/08/31   NaN          의료용 물질 및 의약품 제조업
# 1     (주)CMG제약   58820  2012/12  2001/08/31   NaN          의료용 물질 및 의약품 제조업
# 2     (주)CMG제약   58820  2013/12  2001/08/31   NaN          의료용 물질 및 의약품 제조업
# 3     (주)CMG제약   58820  2014/12  2001/08/31   NaN          의료용 물질 및 의약품 제조업
# 4     (주)CMG제약   58820  2015/12  2001/08/31   NaN          의료용 물질 및 의약품 제조업
# 5     (주)CMG제약   58820  2016/12  2001/08/31   NaN          의료용 물질 및 의약품 제조업
# 6     (주)CMG제약   58820  2017/12  2001/08/31   NaN          의료용 물질 및 의약품 제조업
# 7     (주)CMG제약   58820  2018/12  2001/08/31   NaN          의료용 물질 및 의약품 제조업
# 8     (주)CMG제약   58820  2019/12  2001/08/31   NaN          의료용 물질 및 의약품 제조업
# 9     (주)CMG제약   58820  2020/12  2001/08/31   NaN          의료용 물질 및 의약품 제조업
# 10     (주)ES큐브   50120  2011/12  2002/04/25   NaN               도매 및 상품 중개업
# ...

# %%
all.to_csv('./KOSDAQ/연결개별통합본.csv', encoding='CP949', index=False)

# %%
list = 연결.columns.tolist()
i_list = 개별.columns.tolist()

# %%
i_list
# Out:
# ['회사명',
#  '거래소코드',
#  '회계년도',
#  '상장일',
#  '상장폐지일',
#  '산업명',
#  '소속코드',
#  '[제조]매출액증가율',
#  '[제조]총자본증가율',
#  '[제조]자기자본증가율',
#  '[제조]순이익증가율',
#  '[제조]유형자산증가율',
#  '[제조]비유동자산증가율',
#  '[제조]유동자산증가율',
#  '[제조]재고자산증가율',
#  '[제조]매출액총이익률',
#  '[제조]매출액순이익률',
#  '[제조]총자본사업이익률',
#  '[제조]총자본순이익률',
#  '[제조]자기자본순이익률',
#  '[제조]1주당순이익',
#  '[제조]1주당매출액',
#  '[제조]총자본회전률',
#  '[제조]자기자본회전률',
#  '[제조]비유동자산회전률',
#  '[제조]재고자산회전률',
#  '[제조]매출채권회전률',
#  '[제조]매입채무회전률',
#  '[제조]매입채무회전기간',
#  '[제조]재고자산회전기간',
#  '[제조]매출채권회전기간',
#  '[제조]1회전기간',
#  '[제조]운전자본회전률',
#  '[제조]순운전자본회전률',
#  '[제조]유형자산회전율',
#  '[제조]유동자산회전률',
#  '[제조]당좌자산회전률',
#  '[제조]유동비율',
#  '[제조]당좌비율',
#  '[제조]현금비율',
#  '[제조]순운전자본비율',
#  '[제조]부채비율',
#  '[제조]자기자본배율',
#  '[제조]이자보상배율(이자비용)',
#  '[제조]비유동비율',
#  '[제조]유동자산구성비율',
#  '[제조]자기자본구성비율',
#  '[제조]부가가치',
#  '[제조]총자본투자효율',
#  '[제조]설비투자효율',
#  '[제조]기계투자효율',
#  '[제조]부가가치율',
#  '[제조]노동소득분배율',
#  '[제조]자본분배율',
#  '[제조]이윤분배율']

# %%
for i in list:
    연결[i] = 연결[i].fillna(개별[i])

# %%
연결.isna().sum()
# Out:
# 회사명                     0
# 거래소코드                   0
# 회계년도                    0
# 상장일                     0
# 상장폐지일               10430
# 산업명                     0
# 소속코드                    0
# [제조]매출액증가율            362
# [제조]유형자산증가율           362
# [제조]비유동자산증가율          362
# [제조]총자본증가율            362
# [제조]자기자본증가율           362
# [제조]유동자산증가율           362
# [제조]순이익증가율            362
# [제조]재고자산증가율           362
# [제조]매출액총이익률           362
# [제조]매출액순이익률           362
# [제조]총자본사업이익률          362
# [제조]총자본순이익률           362
# [제조]자기자본순이익률          362
# [제조]1주당순이익            362
# [제조]1주당매출액            362
# [제조]총자본회전률            362
# [제조]자기자본회전률           362
# [제조]비유동자산회전률          362
# [제조]재고자산회전률           362
# [제조]매출채권회전률           362
# [제조]매입채무회전률           362
# [제조]매입채무회전기간          362
# [제조]재고자산회전기간          362
# [제조]매출채권회전기간          362
# [제조]1회전기간             362
# [제조]운전자본회전률           362
# [제조]순운전자본회전률          362
# [제조]유동자산회전률           362
# ...

# %%
연결.to_csv('./KOSDAQ/연결개별통합본.csv', encoding='CP949',index=False)
