# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats.mstats import winsorize
import numpy as np
from scipy.stats import norm
from scipy import stats
from statsmodels.formula.api import ols
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./dataset/이자보상배율최종.csv', encoding='CP949')

# %%
df_c = df[['[제조]매출액증가율',
       '[제조]유형자산증가율', '[제조]비유동자산증가율', '[제조]총자본증가율', '[제조]자기자본증가율',
       '[제조]유동자산증가율', '[제조]순이익증가율', '[제조]재고자산증가율', '[제조]매출액총이익률',
       '[제조]매출액순이익률', '[제조]총자본사업이익률', '[제조]총자본순이익률', '[제조]자기자본순이익률',
       '[제조]1주당순이익', '[제조]1주당매출액', '[제조]총자본회전률', '[제조]자기자본회전률', '[제조]비유동자산회전률',
       '[제조]재고자산회전률', '[제조]매출채권회전률', '[제조]매입채무회전률', '[제조]매입채무회전기간',
       '[제조]재고자산회전기간', '[제조]매출채권회전기간', '[제조]1회전기간', '[제조]운전자본회전률',
       '[제조]순운전자본회전률', '[제조]유동자산회전률', '[제조]당좌자산회전률', '[제조]유동비율', '[제조]당좌비율',
       '[제조]현금비율', '[제조]부채비율', '[제조]순운전자본비율', '[제조]자기자본배율', '[제조]비유동비율',
       '[제조]유동자산구성비율', '[제조]자기자본구성비율', '[제조]부가가치', '[제조]총자본투자효율', '[제조]설비투자효율',
       '[제조]기계투자효율', '[제조]부가가치율', '[제조]노동소득분배율', '[제조]자본분배율', '[제조]이윤분배율',
       '[제조]유형자산회전율', '[제조]이자보상배율(이자비용)']]

# %%
col_n = 4
row_n = 12

fig, ax = plt.subplots(ncols=col_n, nrows=row_n, figsize=(20,row_n*5))


for i,col in enumerate(df_c.columns):
    sns.boxplot(df_c[col],ax=ax[int(i/col_n),int(i%col_n)])

# %%
col_n = 4
row_n = 12

fig, ax = plt.subplots(ncols=col_n, nrows=row_n, figsize=(20,row_n*5))


for i,col in enumerate(df_c.columns):
    sns.distplot(df_c[col], bins=20, ax=ax[int(i/col_n),int(i%col_n)])

# %%
df['[제조]매출액증가율'] = winsorize(df['[제조]매출액증가율'], limits= (0, 0.05))
df['[제조]유형자산증가율'] = winsorize(df['[제조]유형자산증가율'], limits= (0, 0.05))
df['[제조]비유동자산증가율'] = winsorize(df['[제조]비유동자산증가율'], limits= (0, 0.05))
df['[제조]총자본증가율'] = winsorize(df['[제조]총자본증가율'], limits= (0, 0.05))
df['[제조]자기자본증가율'] = winsorize(df['[제조]자기자본증가율'], limits= (0, 0.05))
df['[제조]유동자산증가율'] = winsorize(df['[제조]유동자산증가율'], limits= (0, 0.05))
df['[제조]순이익증가율'] = winsorize(df['[제조]순이익증가율'], limits= (0.025, 0.025))
df['[제조]재고자산증가율'] = winsorize(df['[제조]재고자산증가율'], limits= (0, 0.05))
df['[제조]매출액총이익률'] = winsorize(df['[제조]매출액총이익률'], limits= (0.025, 0.025))
df['[제조]매출액순이익률'] = winsorize(df['[제조]매출액순이익률'], limits= (0.025, 0.025))
df['[제조]총자본사업이익률'] = winsorize(df['[제조]총자본사업이익률'], limits= (0.025, 0.025))
df['[제조]총자본순이익률'] = winsorize(df['[제조]총자본순이익률'], limits= (0.025, 0.025))
df['[제조]자기자본순이익률'] = winsorize(df['[제조]자기자본순이익률'], limits= (0.05, 0))
df['[제조]1주당순이익'] = winsorize(df['[제조]1주당순이익'], limits= (0.025, 0.025))
df['[제조]1주당매출액'] = winsorize(df['[제조]1주당매출액'], limits= (0, 0.05))
df['[제조]총자본회전률'] = winsorize(df['[제조]총자본회전률'], limits= (0, 0.05))
df['[제조]자기자본회전률'] = winsorize(df['[제조]자기자본회전률'], limits= (0, 0.05))
df['[제조]비유동자산회전률'] = winsorize(df['[제조]비유동자산회전률'], limits= (0, 0.05))
df['[제조]재고자산회전률'] = winsorize(df['[제조]재고자산회전률'], limits= (0, 0.05))
df['[제조]매출채권회전률'] = winsorize(df['[제조]매출채권회전률'], limits= (0, 0.05))
df['[제조]매입채무회전률'] = winsorize(df['[제조]매입채무회전률'], limits= (0, 0.05))
df['[제조]매입채무회전기간'] = winsorize(df['[제조]매입채무회전기간'], limits= (0, 0.05))
df['[제조]재고자산회전기간'] = winsorize(df['[제조]재고자산회전기간'], limits= (0, 0.05))
df['[제조]매출채권회전기간'] = winsorize(df['[제조]매출채권회전기간'], limits= (0, 0.05))
df['[제조]1회전기간'] = winsorize(df['[제조]1회전기간'], limits= (0, 0.05))
df['[제조]운전자본회전률'] = winsorize(df['[제조]운전자본회전률'], limits= (0, 0.05))
df['[제조]순운전자본회전률'] = winsorize(df['[제조]순운전자본회전률'], limits= (0, 0.05))
df['[제조]유동자산회전률'] = winsorize(df['[제조]유동자산회전률'], limits= (0, 0.05))
df['[제조]당좌자산회전률'] = winsorize(df['[제조]당좌자산회전률'], limits= (0, 0.05))
df['[제조]유동비율'] = winsorize(df['[제조]유동비율'], limits= (0, 0.05))
df['[제조]당좌비율'] = winsorize(df['[제조]당좌비율'], limits= (0, 0.05))
df['[제조]현금비율'] = winsorize(df['[제조]현금비율'], limits= (0, 0.05))
df['[제조]부채비율'] = winsorize(df['[제조]부채비율'], limits= (0, 0.05))
df['[제조]순운전자본비율'] = winsorize(df['[제조]순운전자본비율'], limits= (0.05, 0))
df['[제조]자기자본배율'] = winsorize(df['[제조]자기자본배율'], limits= (0, 0.05))
df['[제조]비유동비율'] = winsorize(df['[제조]비유동비율'], limits= (0, 0.05))
df['[제조]유동자산구성비율'] = winsorize(df['[제조]유동자산구성비율'], limits= (0.025, 0.025))
df['[제조]자기자본구성비율'] = winsorize(df['[제조]자기자본구성비율'], limits= (0.05, 0))
df['[제조]부가가치'] = winsorize(df['[제조]부가가치'], limits= (0.025, 0.025))
df['[제조]총자본투자효율'] = winsorize(df['[제조]총자본투자효율'], limits= (0.05, 0))
df['[제조]설비투자효율'] = winsorize(df['[제조]설비투자효율'], limits= (0.025, 0.025))
df['[제조]기계투자효율'] = winsorize(df['[제조]기계투자효율'], limits= (0.025, 0.025))
df['[제조]부가가치율'] = winsorize(df['[제조]부가가치율'], limits= (0.025, 0.025))
df['[제조]노동소득분배율'] = winsorize(df['[제조]노동소득분배율'], limits= (0, 0.05))
df['[제조]자본분배율'] = winsorize(df['[제조]자본분배율'], limits= (0.05, 0))
df['[제조]이윤분배율'] = winsorize(df['[제조]이윤분배율'], limits= (0.05, 0))
df['[제조]유형자산회전율'] = winsorize(df['[제조]유형자산회전율'], limits= (0, 0.05))
df['[제조]이자보상배율(이자비용)'] = winsorize(df['[제조]이자보상배율(이자비용)'], limits= (0.025, 0.025))

# %%
df.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '상장일', '상장폐지일', '산업명', '소속코드', '[제조]매출액증가율',
#        '[제조]유형자산증가율', '[제조]비유동자산증가율', '[제조]총자본증가율', '[제조]자기자본증가율',
#        '[제조]유동자산증가율', '[제조]순이익증가율', '[제조]재고자산증가율', '[제조]매출액총이익률',
#        '[제조]매출액순이익률', '[제조]총자본사업이익률', '[제조]총자본순이익률', '[제조]자기자본순이익률',
#        '[제조]1주당순이익', '[제조]1주당매출액', '[제조]총자본회전률', '[제조]자기자본회전률', '[제조]비유동자산회전률',
#        '[제조]재고자산회전률', '[제조]매출채권회전률', '[제조]매입채무회전률', '[제조]매입채무회전기간',
#        '[제조]재고자산회전기간', '[제조]매출채권회전기간', '[제조]1회전기간', '[제조]운전자본회전률',
#        '[제조]순운전자본회전률', '[제조]유동자산회전률', '[제조]당좌자산회전률', '[제조]유동비율', '[제조]당좌비율',
#        '[제조]현금비율', '[제조]부채비율', '[제조]순운전자본비율', '[제조]자기자본배율', '[제조]비유동비율',
#        '[제조]유동자산구성비율', '[제조]자기자본구성비율', '[제조]부가가치', '[제조]총자본투자효율', '[제조]설비투자효율',
#        '[제조]기계투자효율', '[제조]부가가치율', '[제조]노동소득분배율', '[제조]자본분배율', '[제조]이윤분배율',
#        '[제조]유형자산회전율', '[제조]이자보상배율(이자비용)', 'year', 'month', 'label'],
#       dtype='object')

# %%
df_c = df[['[제조]매출액증가율',
       '[제조]유형자산증가율', '[제조]비유동자산증가율', '[제조]총자본증가율', '[제조]자기자본증가율',
       '[제조]유동자산증가율', '[제조]순이익증가율', '[제조]재고자산증가율', '[제조]매출액총이익률',
       '[제조]매출액순이익률', '[제조]총자본사업이익률', '[제조]총자본순이익률', '[제조]자기자본순이익률',
       '[제조]1주당순이익', '[제조]1주당매출액', '[제조]총자본회전률', '[제조]자기자본회전률', '[제조]비유동자산회전률',
       '[제조]재고자산회전률', '[제조]매출채권회전률', '[제조]매입채무회전률', '[제조]매입채무회전기간',
       '[제조]재고자산회전기간', '[제조]매출채권회전기간', '[제조]1회전기간', '[제조]운전자본회전률',
       '[제조]순운전자본회전률', '[제조]유동자산회전률', '[제조]당좌자산회전률', '[제조]유동비율', '[제조]당좌비율',
       '[제조]현금비율', '[제조]부채비율', '[제조]순운전자본비율', '[제조]자기자본배율', '[제조]비유동비율',
       '[제조]유동자산구성비율', '[제조]자기자본구성비율', '[제조]부가가치', '[제조]총자본투자효율', '[제조]설비투자효율',
       '[제조]기계투자효율', '[제조]부가가치율', '[제조]노동소득분배율', '[제조]자본분배율', '[제조]이윤분배율',
       '[제조]유형자산회전율', '[제조]이자보상배율(이자비용)']]

# %%
col_n = 4
row_n = 12

fig, ax = plt.subplots(ncols=col_n, nrows=row_n, figsize=(20,row_n*5))


for i,col in enumerate(df_c.columns):
    sns.distplot(df_c[col], bins=20, ax=ax[int(i/col_n),int(i%col_n)])

# %%
df_c
# Out:
#             회사명  거래소코드                 회계년도         상장일 상장폐지일  \
# 0      (주)CMG제약  58820           2011-12-01  2001-08-31   NaN
# 1      (주)CMG제약  58820           2012-12-01  2001-08-31   NaN
# 2      (주)CMG제약  58820           2013-12-01  2001-08-31   NaN
# 3      (주)CMG제약  58820           2014-12-01  2001-08-31   NaN
# 4      (주)CMG제약  58820           2015-12-01  2001-08-31   NaN
# ...         ...    ...                  ...         ...   ...
# 10657   흥구석유(주)  24060           2016-12-01  1994-12-07   NaN
# 10658   흥구석유(주)  24060           2017-12-01  1994-12-07   NaN
# 10659   흥구석유(주)  24060           2018-12-01  1994-12-07   NaN
# 10660   흥구석유(주)  24060           2019-12-01  1994-12-07   NaN
# 10661   흥구석유(주)  24060  2020-12-01 00:00:00  1994-12-07   NaN
#
#                       산업명  소속코드  [제조]매출액증가율  [제조]유형자산증가율  [제조]비유동자산증가율  ...  \
# 0        의료용 물질 및 의약품 제조업     5       56.40        -5.90        -12.89  ...
# ...

# %%
df_c.max()
# Out:
# [제조]매출액증가율             75.57000
# [제조]유형자산증가율           119.29000
# [제조]비유동자산증가율           97.26000
# [제조]총자본증가율             71.67000
# [제조]자기자본증가율           101.41000
# [제조]유동자산증가율           100.82000
# [제조]순이익증가율            564.63000
# [제조]재고자산증가율           123.63000
# [제조]매출액총이익률            67.89000
# [제조]매출액순이익률            28.03000
# [제조]총자본사업이익률           21.80000
# [제조]총자본순이익률            18.77000
# [제조]자기자본순이익률          348.19000
# [제조]1주당순이익           3174.00000
# [제조]1주당매출액          36483.08000
# [제조]총자본회전률              1.79000
# [제조]자기자본회전률             4.67000
# [제조]비유동자산회전률            6.59000
# [제조]재고자산회전률           217.91000
# [제조]매출채권회전률            20.71000
# [제조]매입채무회전률            86.45000
# [제조]매입채무회전기간           81.54000
# [제조]재고자산회전기간          157.66000
# [제조]매출채권회전기간          162.17000
# [제조]1회전기간               0.07000
# [제조]운전자본회전률             0.67000
# [제조]순운전자본회전률            2.03000
# [제조]유동자산회전률             3.74000
# [제조]당좌자산회전률             5.56000
# ...

# %%
pd.options.display.float_format = '{:.5f}'.format

# %%
df_c.min()
# Out:
# [제조]매출액증가율           -100.00000
# [제조]유형자산증가율          -100.00000
# [제조]비유동자산증가율          -99.47000
# [제조]총자본증가율            -95.84000
# [제조]자기자본증가율         -1068.12000
# [제조]유동자산증가율           -98.81000
# [제조]순이익증가율           -206.32000
# [제조]재고자산증가율           -99.97000
# [제조]매출액총이익률            -5.52000
# [제조]매출액순이익률          -157.46000
# [제조]총자본사업이익률          -21.99000
# [제조]총자본순이익률           -39.36000
# [제조]자기자본순이익률          -58.89000
# [제조]1주당순이익          -1934.00000
# [제조]1주당매출액              0.00000
# [제조]총자본회전률              0.00000
# [제조]자기자본회전률             0.00000
# [제조]비유동자산회전률            0.00000
# [제조]재고자산회전률             0.00000
# [제조]매출채권회전률             0.00000
# [제조]매입채무회전률             0.00000
# [제조]매입채무회전기간            0.00000
# [제조]재고자산회전기간            0.00000
# [제조]매출채권회전기간           -4.74000
# [제조]1회전기간               0.00000
# [제조]운전자본회전률             0.00000
# [제조]순운전자본회전률            0.00000
# [제조]유동자산회전률             0.00000
# [제조]당좌자산회전률             0.00000
# ...

# %%
df['[제조]이자보상배율(이자비용)'].value_counts()
# Out:
#  8432098.32    514
# -4493653.05    123
#  0.62           17
#  1.13           16
#  1.30           15
#               ...
# -33.40           1
#  69.57           1
# -10.95           1
#  10.76           1
# -68.02           1
# Name: [제조]이자보상배율(이자비용), Length: 5403, dtype: int64

# %%
df_c
# Out:
#        [제조]매출액증가율  [제조]유형자산증가율  [제조]비유동자산증가율  [제조]총자본증가율  [제조]자기자본증가율  \
# 0           56.40        -5.90        -12.89        1.98        -2.02
# 1           -8.43        -4.12        -16.43      109.15        75.17
# 2           25.51        16.09         77.05       -2.09        55.10
# 3           11.52        74.30         68.15        3.86         0.01
# 4           18.85        -5.37          1.66       -2.64        -4.48
# ...           ...          ...           ...         ...          ...
# 10657       -7.26        -5.61          0.11        1.39         1.39
# 10658        8.12        -0.56         -0.48        0.98         0.83
# 10659        6.87        -0.36         -2.09       -5.89         0.99
# 10660       -9.35        -7.00         -2.63       11.24         9.31
# 10661      -23.78       -13.92         -8.21        0.07         3.38
#
#        [제조]유동자산증가율  [제조]순이익증가율  [제조]재고자산증가율  [제조]매출액총이익률  [제조]매출액순이익률  ...  \
# ...
