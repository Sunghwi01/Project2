# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('./dataset/21년도상폐기업.csv', encoding='CP949')
df1 = pd.read_csv('./KOSDAQ/21년상폐재무제표.csv', encoding='CP949')
df2 = pd.read_excel('./KOSDAQ/21년상폐재무제표.xlsx')

# %%
df1[df1['회사명']=='(주)미래SCI'].head(3)
# Out:
#          회사명  거래소코드     회계년도  [제조]자산(*)(IFRS)  [제조]자산(*)(IFRS연결)  \
# 19  (주)미래SCI  28040  2011/12       59236211.0         59254859.0
# 20  (주)미래SCI  28040  2012/12       45845613.0         45860077.0
# 21  (주)미래SCI  28040  2013/12       45376560.0         45390811.0
#
#     [제조]      유형자산(*)(IFRS)  [제조]      유형자산(*)(IFRS연결)  [제조]매출액(수익)(*)(IFRS)  \
# 19               43911785.0                 43912476.0            28444885.0
# 20               37563482.0                 37563762.0            21044458.0
# 21               37231445.0                 37231722.0            11263301.0
#
#     [제조]매출액(수익)(*)(IFRS연결)  [제조]   비유동자산(*)(IFRS)  [제조]   비유동자산(*)(IFRS연결)  \
# 19              29432486.0             45425387.0               45441071.0
# 20              21044458.0             38989968.0               39004173.0
# 21              11263301.0             39047907.0               39061902.0
#
#     [제조]   유동자산(*)(IFRS)  [제조]   유동자산(*)(IFRS연결)  [제조]자본(*)(IFRS)  \
# ...

# %%
df[df['회사명']=='(주)미래SCI'].head(3)
# Out:
#          회사명  거래소코드       회계년도  [제조]총자본증가율(IFRS연결)  [제조]유형자산증가율(IFRS연결)  \
# 19  (주)미래SCI  28040 2011-12-01                0.00                 0.00
# 20  (주)미래SCI  28040 2012-12-01                0.00                 0.00
# 21  (주)미래SCI  28040 2013-12-01               -1.02                -0.88
#
#     [제조]비유동자산증가율(IFRS연결)  [제조]유동자산증가율(IFRS연결)  [제조]재고자산증가율(IFRS연결)  \
# 19                  0.00                 0.00                 0.00
# 20                  0.00                 0.00                 0.00
# 21                  0.15                -7.69                -6.39
#
#     [제조]자기자본증가율(IFRS연결)
# 19                 0.00
# 20                 0.00
# 21               112.73

# %% [markdown]
# # 매출액증가율이 0일때 직접 구하기위해 구한 코드식

# %%
df1['총자본증가율'] = (df1['[제조]자산']-df1['[제조]자산'].shift(1))/df1['[제조]자산'].shift(1)
