# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy import stats
from scipy.stats import shapiro
from scipy.stats.mstats import winsorize
from sklearn.linear_model import Lasso, Ridge
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split, cross_val_score
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('./dataset/label지정.csv', encoding='CP949')
df
# Out:
#             회사명  거래소코드      회계년도_x         상장일 상장폐지일                 산업명  \
# 0      (주)CMG제약  58820  2011-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 1      (주)CMG제약  58820  2012-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 2      (주)CMG제약  58820  2013-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 3      (주)CMG제약  58820  2014-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 4      (주)CMG제약  58820  2015-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# ...         ...    ...         ...         ...   ...                 ...
# 10480   흥구석유(주)  24060  2016-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10481   흥구석유(주)  24060  2017-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10482   흥구석유(주)  24060  2018-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10483   흥구석유(주)  24060  2019-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10484   흥구석유(주)  24060  2020-12-01  1994-12-07   NaN         도매 및 상품 중개업
#
#        소속코드  [제조]매출액증가율  [제조]유형자산증가율  [제조]비유동자산증가율  ...  [제조]기계투자효율  \
# 0         5       56.40        -5.90        -12.89  ...      128.51
# 1         5       -8.43        -4.12        -16.43  ...       10.67
# 2         5       25.51        16.09         77.05  ...      289.40
# 3         5       11.52        74.30         68.15  ...      132.06
# 4         5       18.85        -5.37          1.66  ...       90.92
# ...     ...         ...          ...           ...  ...         ...
# 10480     5       -7.26        -5.61          0.11  ...     3684.02
# 10481     5        8.12        -0.56         -0.48  ...     4786.26
# 10482     5        6.87        -0.36         -2.09  ...     3064.10
# 10483     5       -9.35        -7.00         -2.63  ...     3489.21
# 10484     5      -23.78       -13.92         -8.21  ...     3280.80
#
#        [제조]부가가치율  [제조]노동소득분배율  [제조]자본분배율  [제조]이윤분배율  [제조]유형자산회전율  \
# 0          19.56        89.82      10.18     -43.44         1.77
# 1           1.66      1749.87   -1649.87   -2473.07         1.71
# 2          34.29        71.28      28.72       4.23         2.03
# 3          31.04        79.30      20.70       2.24         1.54
# 4          15.96       144.10     -44.10     -84.58         1.48
# ...          ...          ...        ...        ...          ...
# 10480       4.86        48.08      51.92      31.14         3.67
# 10481       4.39        47.63      52.37      30.24         4.10
# 10482       4.44        47.47      52.53      32.14         4.40
# 10483      10.00        22.19      77.81      55.02         4.14
# 10484       8.94        30.41      69.59      46.65         3.52
#
#        [제조]이자보상배율(이자비용)  year  month  label
# 0                  3.53  2011     12      0
# 1                 -7.75  2012     12      0
# 2                  0.70  2013     12      0
# 3                  3.60  2014     12      0
# 4                -32.22  2015     12      0
# ...                 ...   ...    ...    ...
# 10480              7.66  2016     12      0
# 10481              5.91  2017     12      0
# 10482             12.66  2018     12      0
# 10483            252.02  2019     12      0
# 10484              0.00  2020     12      0
#
# [10485 rows x 58 columns]

# %% [markdown]
# ## 윈저라이징 처리

# %%
df_1 = df.copy()
df_1.drop(['회사명', '거래소코드', '회계년도_x', '상장일', '상장폐지일', '산업명', '소속코드','year', 'month'],axis=1,inplace=True)
for col in df_1.columns:
    df_1[col] = winsorize(df_1[col], limits= 0.01)

# %% [markdown]
# # Ridge

# %%
feature = df_1.drop(columns='label')
target = df_1['label']

#릿지 클래서
ridge = Ridge(alpha = 10)

neg_mse_scores = cross_val_score(ridge, feature, target, scoring="neg_mean_squared_error", cv=5)
rmse_scores = np.sqrt(-1 * neg_mse_scores)
avg_rmse = np.mean(rmse_scores)
print(neg_mse_scores,rmse_scores,avg_rmse)

ridge_alphas =[1000,2000,3000,4000,5000]
for alpha in ridge_alphas :
    ridge = Ridge(alpha = alpha)
    neg_mse_scores = cross_val_score(ridge, feature, target, scoring="neg_mean_squared_error", cv=5)
    avg_rmse = np.mean(np.sqrt(-1*neg_mse_scores))
    print('alpha {0} 일 떄 5folds 의 평균 RMSE : {1:.10f}' .format(alpha,avg_rmse))

# fig, axs = plt.subplots(figsize = (18,6), nrows = 1, ncols=5)

coeff_df = pd.DataFrame()

for pos, alpha in enumerate(ridge_alphas):
    ridge = Ridge(alpha= alpha)
    ridge.fit(feature,target)
    coeff = pd.Series(data=ridge.coef_, index=feature.columns)
    colname = 'alpha:' + str(alpha)
    coeff_df[colname] = coeff

    coeff = coeff.sort_values(ascending=False)
#     axs[pos].set_title(colname)
#     axs[pos].set_xlim(-3,6)
#     sns.barplot(x=coeff.values, y=coeff.index, ax =axs[pos])

# plt.show()
# Out:
# [-0.01083252 -0.01583743 -0.01149156 -0.01494932 -0.0118772 ] [0.10407941 0.12584684 0.1071987  0.12226742 0.10898257] 0.11367498779489668
# alpha 1000 일 떄 5folds 의 평균 RMSE : 0.1136804850
# alpha 2000 일 떄 5folds 의 평균 RMSE : 0.1137072121
# alpha 3000 일 떄 5folds 의 평균 RMSE : 0.1137216390
# alpha 4000 일 떄 5folds 의 평균 RMSE : 0.1137308962
# alpha 5000 일 떄 5folds 의 평균 RMSE : 0.1137372542

# %% [markdown]
# ## Ridge의 알파를 조정해 값 확인

# %%
ridge_alphas =[1000,2000,3000,4000,5000]
sort_column = 'alpha:'+str(ridge_alphas[0])
coeff_df.sort_values(by=sort_column, ascending=False)
# Out:
#                     alpha:1000    alpha:2000    alpha:3000    alpha:4000  \
# [제조]순운전자본회전률      6.973753e-03  4.012492e-03  2.756504e-03  2.065047e-03
# [제조]총자본회전률        5.427015e-03  2.795688e-03  1.786608e-03  1.265197e-03
# [제조]비유동자산회전률      1.792822e-03  1.682733e-03  1.532923e-03  1.393357e-03
# [제조]운전자본회전률       1.549225e-03  1.202790e-03  9.808328e-04  8.275429e-04
# [제조]유동자산회전률       9.352702e-04  7.333009e-04  4.678340e-04  2.793329e-04
# [제조]매출채권회전률       7.600413e-04  7.589200e-04  7.578827e-04  7.565238e-04
# [제조]유동자산구성비율      6.950552e-04  6.333245e-04  5.983676e-04  5.757028e-04
# [제조]총자본사업이익률      4.149152e-04  4.326827e-04  4.397398e-04  4.427331e-04
# [제조]자기자본구성비율      3.542577e-04  3.674563e-04  3.717596e-04  3.731123e-04
# [제조]매입채무회전기간      1.436712e-04  1.444661e-04  1.451193e-04  1.456398e-04
# [제조]부채비율          1.410493e-04  1.308688e-04  1.243672e-04  1.197510e-04
# [제조]1회전기간         1.372367e-04  7.289133e-05  4.979775e-05  3.782300e-05
# [제조]매출채권회전기간      1.015192e-04  1.015447e-04  1.018374e-04  1.021616e-04
# [제조]자기자본증가율       8.344129e-05  7.319590e-05  6.751759e-05  6.376047e-05
# [제조]유동자산증가율       6.459754e-05  6.531991e-05  6.566488e-05  6.575821e-05
# [제조]유동비율          6.183586e-05  6.138177e-05  6.069241e-05  6.002560e-05
# [제조]이윤분배율         2.485568e-05  2.405235e-05  2.348263e-05  2.305309e-05
# [제조]매출액총이익률       2.259252e-05  1.953438e-05  1.898258e-05  1.920754e-05
# [제조]매출액증가율        1.373459e-05  1.328384e-05  1.271996e-05  1.220179e-05
# [제조]유형자산증가율       1.220825e-05  1.214928e-05  1.214832e-05  1.216887e-05
# [제조]1주당순이익        9.303671e-06  9.437074e-06  9.519934e-06  9.578655e-06
# [제조]재고자산회전률       3.389436e-06  3.387181e-06  3.378131e-06  3.369963e-06
# [제조]이자보상배율(이자비용)  2.512562e-06  2.586586e-06  2.637535e-06  2.676258e-06
# [제조]설비투자효율        1.831918e-06  1.819876e-06  1.854523e-06  1.896076e-06
# [제조]순이익증가율        4.094059e-07  5.608012e-07  6.193808e-07  6.469135e-07
# [제조]기계투자효율       -4.928117e-09 -5.006257e-09 -5.077251e-09 -5.135624e-09
# [제조]부가가치         -5.087373e-08 -5.245567e-08 -5.307620e-08 -5.341429e-08
# [제조]1주당매출액       -9.033155e-08 -9.683720e-08 -1.032225e-07 -1.087734e-07
# [제조]자기자본배율       -2.637750e-06 -2.592793e-06 -2.552557e-06 -2.518063e-06
# [제조]현금비율         -9.439785e-06 -9.692465e-06 -9.764097e-06 -9.772572e-06
# [제조]매입채무회전률      -1.392701e-05 -1.354164e-05 -1.323913e-05 -1.300515e-05
# [제조]비유동자산증가율     -1.936356e-05 -2.117204e-05 -2.230034e-05 -2.304881e-05
# [제조]유형자산회전율      -2.170606e-05 -1.982678e-05 -1.782202e-05 -1.604226e-05
# [제조]재고자산증가율      -3.030364e-05 -3.039287e-05 -3.042761e-05 -3.044281e-05
# [제조]당좌비율         -4.203507e-05 -4.311462e-05 -4.322711e-05 -4.308384e-05
# [제조]재고자산회전기간     -5.765181e-05 -6.182982e-05 -6.335632e-05 -6.400857e-05
# [제조]부가가치율        -6.095917e-05 -6.981326e-05 -6.971941e-05 -6.732617e-05
# [제조]비유동비율        -7.490960e-05 -8.050115e-05 -8.289000e-05 -8.429652e-05
# [제조]노동소득분배율      -8.322289e-05 -8.565165e-05 -8.764648e-05 -8.928676e-05
# [제조]매출액순이익률      -9.317342e-05 -8.750487e-05 -8.786812e-05 -8.976984e-05
# [제조]총자본투자효율      -1.075947e-04 -8.728958e-05 -8.659555e-05 -9.114172e-05
# [제조]자본분배율        -1.086353e-04 -1.098991e-04 -1.110481e-04 -1.120498e-04
# [제조]자기자본순이익률     -2.828208e-04 -3.004902e-04 -3.107194e-04 -3.179911e-04
# [제조]총자본증가율       -3.420069e-04 -3.275867e-04 -3.194231e-04 -3.139164e-04
# [제조]총자본순이익률      -8.310764e-04 -8.352074e-04 -8.292734e-04 -8.205240e-04
# [제조]순운전자본비율      -1.260400e-03 -1.207697e-03 -1.176462e-03 -1.154320e-03
# [제조]당좌자산회전률      -2.237845e-03 -1.750028e-03 -1.532252e-03 -1.407759e-03
# [제조]자기자본회전률      -1.041094e-02 -8.183084e-03 -6.847408e-03 -5.923806e-03
#
#                     alpha:5000
# [제조]순운전자본회전률      1.630155e-03
# [제조]총자본회전률        9.525538e-04
# [제조]비유동자산회전률      1.270590e-03
# [제조]운전자본회전률       7.153921e-04
# [제조]유동자산회전률       1.488999e-04
# [제조]매출채권회전률       7.549227e-04
# [제조]유동자산구성비율      5.596884e-04
# [제조]총자본사업이익률      4.437159e-04
# [제조]자기자본구성비율      3.731482e-04
# [제조]매입채무회전기간      1.460681e-04
# [제조]부채비율          1.162760e-04
# [제조]1회전기간         3.050535e-05
# [제조]매출채권회전기간      1.024739e-04
# [제조]자기자본증가율       6.104631e-05
# [제조]유동자산증가율       6.571804e-05
# [제조]유동비율          5.941043e-05
# [제조]이윤분배율         2.271386e-05
# [제조]매출액총이익률       1.972693e-05
# [제조]매출액증가율        1.174632e-05
# [제조]유형자산증가율       1.219835e-05
# [제조]1주당순이익        9.623242e-06
# [제조]재고자산회전률       3.363900e-06
# [제조]이자보상배율(이자비용)  2.707318e-06
# [제조]설비투자효율        1.936294e-06
# [제조]순이익증가율        6.606765e-07
# [제조]기계투자효율       -5.183826e-09
# [제조]부가가치         -5.362931e-08
# [제조]1주당매출액       -1.135554e-07
# [제조]자기자본배율       -2.488434e-06
# [제조]현금비율         -9.752683e-06
# [제조]매입채무회전률      -1.281988e-05
# [제조]비유동자산증가율     -2.357425e-05
# [제조]유형자산회전율      -1.450001e-05
# [제조]재고자산증가율      -3.044749e-05
# [제조]당좌비율         -4.284749e-05
# [제조]재고자산회전기간     -6.430428e-05
# [제조]부가가치율        -6.427516e-05
# [제조]비유동비율        -8.527743e-05
# [제조]노동소득분배율      -9.067155e-05
# [제조]매출액순이익률      -9.210147e-05
# [제조]총자본투자효율      -9.727945e-05
# [제조]자본분배율        -1.129333e-04
# [제조]자기자본순이익률     -3.236625e-04
# [제조]총자본증가율       -3.098764e-04
# [제조]총자본순이익률      -8.109931e-04
# [제조]순운전자본비율      -1.137197e-03
# [제조]당좌자산회전률      -1.322412e-03
# [제조]자기자본회전률      -5.237524e-03

# %% [markdown]
# # Lasso

# %%
feature = df_1.drop(columns='label')
target = df_1['label']

lasso = Lasso(alpha = 10)
lasso_alphas =[0,1,0.03,0.04,0.05,0.1]

neg_mse_scores = cross_val_score(lasso, feature, target, scoring="neg_mean_squared_error", cv=5)
rmse_scores = np.sqrt(-1 * neg_mse_scores)
avg_rmse = np.mean(rmse_scores)
print(neg_mse_scores,rmse_scores,avg_rmse)

# lasso_alphas =[100,10000,10000]
for alpha in lasso_alphas :
    lasso = Lasso(alpha = alpha)
    neg_mse_scores = cross_val_score(lasso, feature, target, scoring="neg_mean_squared_error", cv=5)
    avg_rmse = np.mean(np.sqrt(-1*neg_mse_scores))
    print('alpha {0} 일 떄 5folds 의 평균 RMSE : {1:10f}' .format(alpha,avg_rmse))

# fig, axs = plt.subplots(figsize = (18,6), nrows = 1, ncols=5)

coeff_df = pd.DataFrame()

for pos, alpha in enumerate(lasso_alphas):
    lasso = Lasso(alpha = alpha)
    lasso.fit(feature,target)
    coeff = pd.Series(data=lasso.coef_, index=feature.columns)
    colname = 'alpha:' + str(alpha)
    coeff_df[colname] = coeff

    coeff = coeff.sort_values(ascending=False)
# Out:
# [-0.01124908 -0.01720613 -0.01218077 -0.01539911 -0.01267597] [0.10606167 0.13117214 0.11036652 0.12409314 0.1125876 ] 0.11685621574036827
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:593: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 55.044498513686456, tolerance: 0.012119635193133055
#   model = cd_fast.enet_coordinate_descent(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:593: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.86372476856177, tolerance: 0.010855746304244162
#   model = cd_fast.enet_coordinate_descent(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:593: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54.34125216610852, tolerance: 0.011925453028135444
#   model = cd_fast.enet_coordinate_descent(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:593: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50.66795123813317, tolerance: 0.011245064377682391
#   model = cd_fast.enet_coordinate_descent(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:593: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53.90627783497227, tolerance: 0.01182832618025753
#   model = cd_fast.enet_coordinate_descent(
# alpha 0 일 떄 5folds 의 평균 RMSE :   0.113716
# alpha 1 일 떄 5folds 의 평균 RMSE :   0.115963
# alpha 0.03 일 떄 5folds 의 평균 RMSE :   0.113599
# alpha 0.04 일 떄 5folds 의 평균 RMSE :   0.113624
# alpha 0.05 일 떄 5folds 의 평균 RMSE :   0.113656
# alpha 0.1 일 떄 5folds 의 평균 RMSE :   0.113825
# <ipython-input-10-4d085b2091dc>:25: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   lasso.fit(feature,target)
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66.17577594150262, tolerance: 0.01449390557939916
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# ## Lasso의 알파를 조정해 값 확인

# %%
lasso_alphas =[0,0.01,0.03,0.04,0.05]

sort_column = 'alpha:'+str(lasso_alphas[0])
coeff_df.sort_values(by=sort_column, ascending=False)
# Out:
#                        alpha:0       alpha:1    alpha:0.03    alpha:0.04  \
# [제조]총자본회전률        3.146048e-02 -0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]순운전자본회전률      2.116306e-02 -0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]1회전기간         1.509228e-02  0.000000e+00  0.000000e+00  0.000000e+00
# [제조]운전자본회전률       1.998974e-03  0.000000e+00  0.000000e+00  0.000000e+00
# [제조]비유동자산회전률      9.409503e-04 -0.000000e+00  0.000000e+00  0.000000e+00
# [제조]매출채권회전률       7.668542e-04  0.000000e+00  2.364699e-05  0.000000e+00
# [제조]유동자산구성비율      7.616900e-04 -0.000000e+00  0.000000e+00  0.000000e+00
# [제조]총자본사업이익률      3.351343e-04 -0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]자기자본구성비율      2.793336e-04 -0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]부채비율          1.728461e-04  5.216581e-05  7.897560e-05  6.754095e-05
# [제조]매입채무회전기간      1.431968e-04  0.000000e+00  1.239126e-04  1.167355e-04
# [제조]자기자본증가율       1.207844e-04 -0.000000e+00  6.606218e-06  0.000000e+00
# [제조]매출채권회전기간      1.095028e-04  0.000000e+00  3.775470e-05  3.312760e-05
# [제조]유동자산증가율       7.208304e-05 -0.000000e+00  0.000000e+00  0.000000e+00
# [제조]유동비율          5.536814e-05 -1.411070e-06  8.459753e-06  0.000000e+00
# [제조]매출액총이익률       4.314169e-05 -0.000000e+00  0.000000e+00  0.000000e+00
# [제조]부가가치율         3.561238e-05 -0.000000e+00 -8.631981e-05 -1.097503e-04
# [제조]이윤분배율         2.598681e-05 -0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]유형자산증가율       1.253507e-05 -0.000000e+00  7.233317e-06  4.264003e-06
# [제조]매출액증가율        1.102101e-05 -0.000000e+00  0.000000e+00  0.000000e+00
# [제조]1주당순이익        8.999074e-06 -3.753075e-06  9.468674e-06  9.085525e-06
# [제조]재고자산회전률       3.293450e-06  0.000000e+00  3.566600e-06  3.580325e-06
# [제조]설비투자효율        2.409826e-06 -3.925694e-06  2.173921e-06  1.869706e-06
# [제조]이자보상배율(이자비용)  2.399281e-06  0.000000e+00  3.037250e-06  2.884134e-06
# [제조]기계투자효율       -5.151896e-09 -5.241733e-09 -4.830245e-09 -4.703272e-09
# [제조]부가가치         -3.761324e-08 -1.384278e-07 -7.063365e-08 -7.492469e-08
# [제조]1주당매출액       -1.015083e-07  5.451815e-08 -1.579034e-07 -1.499331e-07
# [제조]순이익증가율       -4.831660e-07  0.000000e+00  5.937409e-09  0.000000e+00
# [제조]자기자본배율       -2.668106e-06 -3.172749e-06 -2.448752e-06 -2.507616e-06
# [제조]현금비율         -7.327523e-06 -0.000000e+00 -3.549235e-06 -3.062564e-06
# [제조]유형자산회전율      -1.167791e-05  0.000000e+00  0.000000e+00  0.000000e+00
# [제조]매입채무회전률      -1.391334e-05 -0.000000e+00 -2.829894e-06 -1.384174e-06
# [제조]비유동자산증가율     -1.946256e-05 -0.000000e+00 -4.754104e-05 -4.413047e-05
# [제조]당좌비율         -2.827210e-05 -0.000000e+00  1.974815e-06  8.215690e-06
# [제조]재고자산증가율      -2.938881e-05 -0.000000e+00 -2.495307e-05 -2.429404e-05
# [제조]재고자산회전기간     -4.086012e-05  0.000000e+00 -2.788110e-05 -1.743206e-05
# [제조]비유동비율        -4.315382e-05  0.000000e+00 -7.099960e-05 -3.184754e-05
# [제조]노동소득분배율      -8.327177e-05 -0.000000e+00 -7.680138e-05 -5.471934e-05
# [제조]자본분배율        -1.100351e-04 -0.000000e+00 -6.376208e-05 -4.059025e-05
# [제조]매출액순이익률      -1.575518e-04 -0.000000e+00 -1.279450e-04 -1.225102e-04
# [제조]자기자본순이익률     -2.068319e-04 -0.000000e+00 -5.222472e-04 -5.228371e-04
# [제조]총자본투자효율      -3.045085e-04 -0.000000e+00 -1.172469e-04 -6.440804e-05
# [제조]총자본증가율       -3.965404e-04 -0.000000e+00 -1.344786e-04 -1.197734e-04
# [제조]총자본순이익률      -7.689098e-04 -0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]순운전자본비율      -1.416228e-03 -0.000000e+00 -3.919701e-04 -2.996683e-04
# [제조]당좌자산회전률      -2.979604e-03 -0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]유동자산회전률      -6.682341e-03 -0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]자기자본회전률      -1.794660e-02 -0.000000e+00 -0.000000e+00 -0.000000e+00
#
#                     alpha:0.05     alpha:0.1
# [제조]총자본회전률       -0.000000e+00 -0.000000e+00
# [제조]순운전자본회전률     -0.000000e+00 -0.000000e+00
# [제조]1회전기간         0.000000e+00  0.000000e+00
# [제조]운전자본회전률       0.000000e+00  0.000000e+00
# [제조]비유동자산회전률      0.000000e+00 -0.000000e+00
# [제조]매출채권회전률       0.000000e+00  0.000000e+00
# [제조]유동자산구성비율      0.000000e+00 -0.000000e+00
# [제조]총자본사업이익률     -0.000000e+00 -0.000000e+00
# [제조]자기자본구성비율     -0.000000e+00 -0.000000e+00
# [제조]부채비율          5.913700e-05  8.079527e-05
# [제조]매입채무회전기간      1.097571e-04  4.384715e-05
# [제조]자기자본증가율       0.000000e+00 -0.000000e+00
# [제조]매출채권회전기간      3.147537e-05  1.189070e-05
# [제조]유동자산증가율      -0.000000e+00 -0.000000e+00
# [제조]유동비율          0.000000e+00 -1.489426e-06
# [제조]매출액총이익률       0.000000e+00 -0.000000e+00
# [제조]부가가치율        -1.272929e-04 -8.106786e-05
# [제조]이윤분배율        -0.000000e+00 -0.000000e+00
# [제조]유형자산증가율       1.406351e-06  0.000000e+00
# [제조]매출액증가율       -0.000000e+00 -0.000000e+00
# [제조]1주당순이익        8.684748e-06  6.924170e-06
# [제조]재고자산회전률       3.694243e-06  3.352559e-06
# [제조]설비투자효율        1.576185e-06  3.628255e-08
# [제조]이자보상배율(이자비용)  2.750335e-06  2.369779e-06
# [제조]기계투자효율       -4.604121e-09 -4.422111e-09
# [제조]부가가치         -7.901867e-08 -8.937946e-08
# [제조]1주당매출액       -1.442601e-07 -1.207723e-07
# [제조]순이익증가율        0.000000e+00  0.000000e+00
# [제조]자기자본배율       -2.533855e-06 -2.568263e-06
# [제조]현금비율         -2.656661e-06 -3.069676e-06
# [제조]유형자산회전율       0.000000e+00  0.000000e+00
# [제조]매입채무회전률      -2.265302e-07 -0.000000e+00
# [제조]비유동자산증가율     -4.015551e-05 -2.607899e-05
# [제조]당좌비율          5.697732e-06 -0.000000e+00
# [제조]재고자산증가율      -2.371858e-05 -2.193831e-05
# [제조]재고자산회전기간     -1.269100e-05 -0.000000e+00
# [제조]비유동비율        -0.000000e+00  0.000000e+00
# [제조]노동소득분배율      -3.305227e-05 -1.270064e-05
# [제조]자본분배율        -1.790359e-05 -0.000000e+00
# [제조]매출액순이익률      -1.218276e-04 -1.618501e-04
# [제조]자기자본순이익률     -5.237955e-04 -4.376459e-04
# [제조]총자본투자효율      -1.445470e-05 -0.000000e+00
# [제조]총자본증가율       -1.113094e-04 -9.146936e-05
# [제조]총자본순이익률      -0.000000e+00 -0.000000e+00
# [제조]순운전자본비율      -2.219631e-04 -5.779972e-05
# [제조]당좌자산회전률      -0.000000e+00 -0.000000e+00
# [제조]유동자산회전률      -0.000000e+00 -0.000000e+00
# [제조]자기자본회전률      -0.000000e+00 -0.000000e+00

# %%
a = coeff_df[coeff_df["alpha:0.03"]!=0]                     ## 알파값이 0.03일때 0값이 아닌 데이터
a = a["alpha:0.03"].abs()                                   ## 해당 데이터의 절대값
a
# Out:
# [제조]유형자산증가율         7.233317e-06
# [제조]비유동자산증가율        4.754104e-05
# [제조]총자본증가율          1.344786e-04
# [제조]자기자본증가율         6.606218e-06
# [제조]순이익증가율          5.937409e-09
# [제조]재고자산증가율         2.495307e-05
# [제조]매출액순이익률         1.279450e-04
# [제조]자기자본순이익률        5.222472e-04
# [제조]1주당순이익          9.468674e-06
# [제조]1주당매출액          1.579034e-07
# [제조]재고자산회전률         3.566600e-06
# [제조]매출채권회전률         2.364699e-05
# [제조]매입채무회전률         2.829894e-06
# [제조]매입채무회전기간        1.239126e-04
# [제조]재고자산회전기간        2.788110e-05
# [제조]매출채권회전기간        3.775470e-05
# [제조]유동비율            8.459753e-06
# [제조]당좌비율            1.974815e-06
# [제조]현금비율            3.549235e-06
# [제조]부채비율            7.897560e-05
# [제조]순운전자본비율         3.919701e-04
# [제조]자기자본배율          2.448752e-06
# [제조]비유동비율           7.099960e-05
# [제조]부가가치            7.063365e-08
# [제조]총자본투자효율         1.172469e-04
# [제조]설비투자효율          2.173921e-06
# [제조]기계투자효율          4.830245e-09
# [제조]부가가치율           8.631981e-05
# [제조]노동소득분배율         7.680138e-05
# [제조]자본분배율           6.376208e-05
# [제조]이자보상배율(이자비용)    3.037250e-06
# Name: alpha:0.03, dtype: float64

# %%
a= pd.DataFrame(a)
a=a.sort_values(["alpha:0.03"],ascending=True)
a
# Out:
#                     alpha:0.03
# [제조]기계투자효율        4.830245e-09
# [제조]순이익증가율        5.937409e-09
# [제조]부가가치          7.063365e-08
# [제조]1주당매출액        1.579034e-07
# [제조]당좌비율          1.974815e-06
# [제조]설비투자효율        2.173921e-06
# [제조]자기자본배율        2.448752e-06
# [제조]매입채무회전률       2.829894e-06
# [제조]이자보상배율(이자비용)  3.037250e-06
# [제조]현금비율          3.549235e-06
# [제조]재고자산회전률       3.566600e-06
# [제조]자기자본증가율       6.606218e-06
# [제조]유형자산증가율       7.233317e-06
# [제조]유동비율          8.459753e-06
# [제조]1주당순이익        9.468674e-06
# [제조]매출채권회전률       2.364699e-05
# [제조]재고자산증가율       2.495307e-05
# [제조]재고자산회전기간      2.788110e-05
# [제조]매출채권회전기간      3.775470e-05
# [제조]비유동자산증가율      4.754104e-05
# [제조]자본분배율         6.376208e-05
# [제조]비유동비율         7.099960e-05
# [제조]노동소득분배율       7.680138e-05
# [제조]부채비율          7.897560e-05
# [제조]부가가치율         8.631981e-05
# [제조]총자본투자효율       1.172469e-04
# [제조]매입채무회전기간      1.239126e-04
# [제조]매출액순이익률       1.279450e-04
# [제조]총자본증가율        1.344786e-04
# [제조]순운전자본비율       3.919701e-04
# [제조]자기자본순이익률      5.222472e-04

# %%
feature = pd.DataFrame(a)
feature.index 
feature = df[['[제조]노동소득분배율','[제조]비유동자산증가율', '[제조]부채비율',
            '[제조]총자본투자효율', '[제조]매입채무회전기간', '[제조]매출액순이익률',
            '[제조]총자본증가율', '[제조]순운전자본비율', '[제조]자기자본순이익률']]

# %% [markdown]
# ### 피처 선정을 위한 VIF & 히트맵

# %%
def vif(data):
    import pandas as pd
    from statsmodels.stats.outliers_influence import variance_inflation_factor

    # VIF 출력을 위한 데이터 프레임 형성
    vif = pd.DataFrame()

    # VIF 값과 각 Feature 이름에 대해 설정
    vif["VIF Factor"] = [variance_inflation_factor(data.values, i) for i in range(len(data.columns))]
    vif["features"] = data.columns 

    # VIF 값이 높은 순으로 정렬
    vif = vif.sort_values(by="VIF Factor", ascending=False)
    vif = vif.reset_index().drop(columns='index')
    
    return vif

vif(feature)
# vif 랑 회귀계수 비교해서 vif가 크면서 회귀계수가 작은얘들을 제거
# Out:
#    VIF Factor      features
# 0    1.523278   [제조]순운전자본비율
# 1    1.497246   [제조]총자본투자효율
# 2    1.470721    [제조]총자본증가율
# 3    1.380020  [제조]비유동자산증가율
# 4    1.153694  [제조]매입채무회전기간
# 5    1.040907   [제조]매출액순이익률
# 6    1.031671      [제조]부채비율
# 7    1.004488  [제조]자기자본순이익률
# 8    1.003715   [제조]노동소득분배율

# %%
def corr_heatmap(dataset, method_option = 'pearson'):

    
    # heatmap 그리기
    mask_ut=np.triu(np.ones(dataset.corr().shape)).astype(bool) 
    plt.figure(figsize=(80,80))
    sns.heatmap(dataset.corr(method=method_option), annot = True, cmap = 'RdYlBu_r', cbar_kws={"shrink": .5}, 
                annot_kws={"size": 20}, linewidths=.5, mask=mask_ut)
    plt.show()

# 함수 사용
corr_heatmap(feature)

# %% [markdown]
# # ElasticNet

# %%
from sklearn.linear_model import ElasticNet
elasticNet = ElasticNet(alpha = 10)
elasticNet_alphas =[0.04,0.05,0.06,0.07,0.08]

feature = df_1.drop(columns='label')
target = df_1['label']


neg_mse_scores = cross_val_score(elasticNet, feature, target, scoring="neg_mean_squared_error", cv=5)
rmse_scores = np.sqrt(-1 * neg_mse_scores)
avg_rmse = np.mean(rmse_scores)
print(neg_mse_scores,rmse_scores,avg_rmse)

for alpha in elasticNet_alphas :
    elasticNet  = ElasticNet(alpha = alpha, l1_ratio=0.5)
    neg_mse_scores = cross_val_score(elasticNet, feature, target, scoring="neg_mean_squared_error", cv=5)
    avg_rmse = np.mean(np.sqrt(-1*neg_mse_scores))
    print('alpha {0} 일 떄 5folds 의 평균 RMSE : {1:10f}' .format(alpha,avg_rmse))

# fig, axs = plt.subplots(figsize = (18,6), nrows = 1, ncols=5)

coeff_df = pd.DataFrame()

for pos, alpha in enumerate(elasticNet_alphas):
    
    elasticNet = ElasticNet(alpha = alpha, l1_ratio=0.5)
    elasticNet.fit(feature,target)
    coeff = pd.Series(data=elasticNet.coef_, index=feature.columns)
    colname = 'alpha:' + str(alpha)
    coeff_df[colname] = coeff

    coeff = coeff.sort_values(ascending=False)
# Out:
# [-0.01119489 -0.01716795 -0.01213731 -0.01534101 -0.01261969] [0.10580589 0.13102654 0.11016948 0.12385884 0.1123374 ] 0.11663962912511276
# alpha 0.04 일 떄 5folds 의 평균 RMSE :   0.113606
# alpha 0.05 일 떄 5folds 의 평균 RMSE :   0.113595
# alpha 0.06 일 떄 5folds 의 평균 RMSE :   0.113599
# alpha 0.07 일 떄 5folds 의 평균 RMSE :   0.113610
# alpha 0.08 일 떄 5folds 의 평균 RMSE :   0.113624

# %%
elasticNet_alphas =[0.04,0.05,0.06,0.07,0.08]               # l1_ratio = 0.5, alphas =0.05 최적

sort_column = 'alpha:'+str(elasticNet_alphas[0])
coeff_df.sort_values(by=sort_column, ascending=False)
# Out:
#                     alpha:0.04    alpha:0.05    alpha:0.06    alpha:0.07  \
# [제조]매출채권회전률       2.548520e-04  1.392396e-04  2.363097e-05  0.000000e+00
# [제조]매입채무회전기간      1.303236e-04  1.272763e-04  1.239103e-04  1.204047e-04
# [제조]부채비율          8.802496e-05  8.363003e-05  7.897287e-05  7.306826e-05
# [제조]매출채권회전기간      6.256665e-05  5.020259e-05  3.775186e-05  3.413904e-05
# [제조]자기자본증가율       2.143965e-05  1.413845e-05  6.601383e-06  0.000000e+00
# [제조]유동비율          1.318219e-05  1.170348e-05  8.454970e-06  3.151074e-06
# [제조]유형자산증가율       9.786066e-06  8.521906e-06  7.233077e-06  5.688249e-06
# [제조]1주당순이익        9.764533e-06  9.617513e-06  9.468263e-06  9.288822e-06
# [제조]재고자산회전률       3.511118e-06  3.546621e-06  3.566483e-06  3.556631e-06
# [제조]이자보상배율(이자비용)  3.216511e-06  3.126959e-06  3.037187e-06  2.951722e-06
# [제조]유동자산증가율       3.037585e-06  0.000000e+00  0.000000e+00  0.000000e+00
# [제조]설비투자효율        2.323534e-06  2.254479e-06  2.173761e-06  2.024169e-06
# [제조]순이익증가율        6.523634e-08  3.477874e-08  6.105343e-09  0.000000e+00
# [제조]유동자산구성비율      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# [제조]자기자본구성비율     -0.000000e+00 -0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]당좌자산회전률      -0.000000e+00 -0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]유동자산회전률      -0.000000e+00 -0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]순운전자본회전률     -0.000000e+00 -0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]운전자본회전률       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# [제조]이윤분배율         0.000000e+00  0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]유형자산회전율       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# [제조]당좌비율          0.000000e+00  0.000000e+00  1.977186e-06  6.233693e-06
# [제조]매출액증가율        0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# [제조]1회전기간         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# [제조]매출액총이익률       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# [제조]비유동자산회전률      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# [제조]자기자본회전률      -0.000000e+00 -0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]총자본회전률       -0.000000e+00 -0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]총자본순이익률      -0.000000e+00 -0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]총자본사업이익률      0.000000e+00  0.000000e+00 -0.000000e+00 -0.000000e+00
# [제조]기계투자효율       -5.194889e-09 -5.013871e-09 -4.830290e-09 -4.755279e-09
# [제조]부가가치         -6.677213e-08 -6.870604e-08 -7.063541e-08 -7.289957e-08
# [제조]1주당매출액       -1.668467e-07 -1.625295e-07 -1.578996e-07 -1.534218e-07
# [제조]자기자본배율       -2.353026e-06 -2.400587e-06 -2.448772e-06 -2.486959e-06
# [제조]현금비율         -5.319134e-06 -4.354272e-06 -3.550867e-06 -3.208182e-06
# [제조]매입채무회전률      -6.315038e-06 -4.557864e-06 -2.829643e-06 -1.996240e-06
# [제조]재고자산증가율      -2.545338e-05 -2.520794e-05 -2.495383e-05 -2.466641e-05
# [제조]재고자산회전기간     -3.541624e-05 -3.233982e-05 -2.788125e-05 -2.193779e-05
# [제조]비유동자산증가율     -4.992258e-05 -4.940531e-05 -4.754226e-05 -4.601141e-05
# [제조]부가가치율        -6.913534e-05 -7.700340e-05 -8.631836e-05 -9.828756e-05
# [제조]자본분배율        -8.459766e-05 -7.431189e-05 -6.377459e-05 -5.244517e-05
# [제조]노동소득분배율      -9.681547e-05 -8.692368e-05 -7.681149e-05 -6.602604e-05
# [제조]비유동비율        -1.071175e-04 -8.921264e-05 -7.096689e-05 -5.119183e-05
# [제조]매출액순이익률      -1.261892e-04 -1.277966e-04 -1.279547e-04 -1.251124e-04
# [제조]총자본투자효율      -1.562918e-04 -1.374592e-04 -1.172609e-04 -9.048032e-05
# [제조]총자본증가율       -1.616606e-04 -1.457765e-04 -1.344751e-04 -1.237971e-04
# [제조]순운전자본비율      -4.823320e-04 -4.372401e-04 -3.918711e-04 -3.449921e-04
# [제조]자기자본순이익률     -5.287033e-04 -5.252347e-04 -5.221872e-04 -5.219543e-04
#
#                     alpha:0.08
# [제조]매출채권회전률       0.000000e+00
# [제조]매입채무회전기간      1.167316e-04
# [제조]부채비율          6.754114e-05
# [제조]매출채권회전기간      3.312608e-05
# [제조]자기자본증가율       0.000000e+00
# [제조]유동비율          0.000000e+00
# [제조]유형자산증가율       4.263886e-06
# [제조]1주당순이익        9.085003e-06
# [제조]재고자산회전률       3.580202e-06
# [제조]이자보상배율(이자비용)  2.884120e-06
# [제조]유동자산증가율       0.000000e+00
# [제조]설비투자효율        1.869572e-06
# [제조]순이익증가율        0.000000e+00
# [제조]유동자산구성비율      0.000000e+00
# [제조]자기자본구성비율     -0.000000e+00
# [제조]당좌자산회전률      -0.000000e+00
# [제조]유동자산회전률      -0.000000e+00
# [제조]순운전자본회전률     -0.000000e+00
# [제조]운전자본회전률       0.000000e+00
# [제조]이윤분배율        -0.000000e+00
# [제조]유형자산회전율       0.000000e+00
# [제조]당좌비율          8.212704e-06
# [제조]매출액증가율        0.000000e+00
# [제조]1회전기간         0.000000e+00
# [제조]매출액총이익률       0.000000e+00
# [제조]비유동자산회전률      0.000000e+00
# [제조]자기자본회전률      -0.000000e+00
# [제조]총자본회전률       -0.000000e+00
# [제조]총자본순이익률      -0.000000e+00
# [제조]총자본사업이익률     -0.000000e+00
# [제조]기계투자효율       -4.703349e-09
# [제조]부가가치         -7.492637e-08
# [제조]1주당매출액       -1.499284e-07
# [제조]자기자본배율       -2.507634e-06
# [제조]현금비율         -3.064399e-06
# [제조]매입채무회전률      -1.384361e-06
# [제조]재고자산증가율      -2.429504e-05
# [제조]재고자산회전기간     -1.743688e-05
# [제조]비유동자산증가율     -4.413182e-05
# [제조]부가가치율        -1.097322e-04
# [제조]자본분배율        -4.060866e-05
# [제조]노동소득분배율      -5.473461e-05
# [제조]비유동비율        -3.181587e-05
# [제조]매출액순이익률      -1.225319e-04
# [제조]총자본투자효율      -6.445317e-05
# [제조]총자본증가율       -1.197759e-04
# [제조]순운전자본비율      -2.995684e-04
# [제조]자기자본순이익률     -5.227513e-04

# %%
a = coeff_df[coeff_df["alpha:0.05"]!=0]
a = a["alpha:0.05"].abs()
a
# Out:
# [제조]유형자산증가율         8.521906e-06
# [제조]비유동자산증가율        4.940531e-05
# [제조]총자본증가율          1.457765e-04
# [제조]자기자본증가율         1.413845e-05
# [제조]순이익증가율          3.477874e-08
# [제조]재고자산증가율         2.520794e-05
# [제조]매출액순이익률         1.277966e-04
# [제조]자기자본순이익률        5.252347e-04
# [제조]1주당순이익          9.617513e-06
# [제조]1주당매출액          1.625295e-07
# [제조]재고자산회전률         3.546621e-06
# [제조]매출채권회전률         1.392396e-04
# [제조]매입채무회전률         4.557864e-06
# [제조]매입채무회전기간        1.272763e-04
# [제조]재고자산회전기간        3.233982e-05
# [제조]매출채권회전기간        5.020259e-05
# [제조]유동비율            1.170348e-05
# [제조]현금비율            4.354272e-06
# [제조]부채비율            8.363003e-05
# [제조]순운전자본비율         4.372401e-04
# [제조]자기자본배율          2.400587e-06
# [제조]비유동비율           8.921264e-05
# [제조]부가가치            6.870604e-08
# [제조]총자본투자효율         1.374592e-04
# [제조]설비투자효율          2.254479e-06
# [제조]기계투자효율          5.013871e-09
# [제조]부가가치율           7.700340e-05
# [제조]노동소득분배율         8.692368e-05
# [제조]자본분배율           7.431189e-05
# [제조]이자보상배율(이자비용)    3.126959e-06
# Name: alpha:0.05, dtype: float64

# %%
a= pd.DataFrame(a)
a=a.sort_values(["alpha:0.05"],ascending=True)
a
# Out:
#                     alpha:0.05
# [제조]기계투자효율        5.013871e-09
# [제조]순이익증가율        3.477874e-08
# [제조]부가가치          6.870604e-08
# [제조]1주당매출액        1.625295e-07
# [제조]설비투자효율        2.254479e-06
# [제조]자기자본배율        2.400587e-06
# [제조]이자보상배율(이자비용)  3.126959e-06
# [제조]재고자산회전률       3.546621e-06
# [제조]현금비율          4.354272e-06
# [제조]매입채무회전률       4.557864e-06
# [제조]유형자산증가율       8.521906e-06
# [제조]1주당순이익        9.617513e-06
# [제조]유동비율          1.170348e-05
# [제조]자기자본증가율       1.413845e-05
# [제조]재고자산증가율       2.520794e-05
# [제조]재고자산회전기간      3.233982e-05
# [제조]비유동자산증가율      4.940531e-05
# [제조]매출채권회전기간      5.020259e-05
# [제조]자본분배율         7.431189e-05
# [제조]부가가치율         7.700340e-05
# [제조]부채비율          8.363003e-05
# [제조]노동소득분배율       8.692368e-05
# [제조]비유동비율         8.921264e-05
# [제조]매입채무회전기간      1.272763e-04
# [제조]매출액순이익률       1.277966e-04
# [제조]총자본투자효율       1.374592e-04
# [제조]매출채권회전률       1.392396e-04
# [제조]총자본증가율        1.457765e-04
# [제조]순운전자본비율       4.372401e-04
# [제조]자기자본순이익률      5.252347e-04

# %%
feature = pd.DataFrame(a)
feature.index 
feature = df[['[제조]노동소득분배율', '[제조]비유동비율','[제조]매입채무회전기간', 
            '[제조]매출액순이익률', '[제조]총자본투자효율', '[제조]매출채권회전률',
            '[제조]총자본증가율', '[제조]순운전자본비율', '[제조]자기자본순이익률']]

# %%
def vif(data):
    import pandas as pd
    from statsmodels.stats.outliers_influence import variance_inflation_factor

    # VIF 출력을 위한 데이터 프레임 형성
    vif = pd.DataFrame()

    # VIF 값과 각 Feature 이름에 대해 설정
    vif["VIF Factor"] = [variance_inflation_factor(data.values, i) for i in range(len(data.columns))]
    vif["features"] = data.columns 

    # VIF 값이 높은 순으로 정렬
    vif = vif.sort_values(by="VIF Factor", ascending=False)
    vif = vif.reset_index().drop(columns='index')
    
    return vif

vif(feature)
# Out:
#    VIF Factor      features
# 0    1.533364   [제조]순운전자본비율
# 1    1.510722   [제조]총자본투자효율
# 2    1.182426  [제조]매입채무회전기간
# 3    1.090089    [제조]총자본증가율
# 4    1.072024     [제조]비유동비율
# 5    1.039853   [제조]매출액순이익률
# 6    1.018103   [제조]매출채권회전률
# 7    1.004513  [제조]자기자본순이익률
# 8    1.003772   [제조]노동소득분배율
