# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./dataset/부도기업사유(성휘).csv', encoding='CP949')

# %%
df5 = pd.read_csv('./dataset/증가율수정데이터(성휘).csv', encoding='CP949')

# %%
df['회사명'].value_counts()
# Out:
# (주)에스마크        9
# (주)바이오빌        9
# (주)에스에프씨       9
# 에스케이씨솔믹스(주)    9
# 이엘케이(주)        9
#               ..
# 어울림엘시스(주)      1
# (주)시노펙스그린테크    1
# 성융광전투자유한공사     1
# (주)트라이써클       1
# (주)엔스퍼트        1
# Name: 회사명, Length: 222, dtype: int64

# %%
df_delete = df[df['삭제여부']!='삭제'].index
df = df.drop(df_delete)

# %%
list_a = df['회사명'].unique().tolist()

# %%
list
# Out:
# ['(주)극동자동화',
#  '(주)금오하이텍',
#  '(주)나이코',
#  '(주)다린',
#  '(주)대원모방',
#  '(주)더블유게임즈',
#  '(주)동서',
#  '(주)동성하이켐',
#  '(주)미래자원엠엘',
#  '(주)본느',
#  '(주)비앤에스미디어',
#  '(주)비엔에프코퍼레이션',
#  '(주)세기리텍',
#  '(주)셀트리온',
#  '(주)스페이스솔루션',
#  '(주)시냅스엠',
#  '(주)시노펙스그린테크',
#  '(주)심팩메탈',
#  '(주)씨티네트웍스',
#  '(주)아이엘사이언스',
#  '(주)알로이스',
#  '(주)에스와이이노베이션',
#  '(주)에스와이제이',
#  '(주)에이치앤아이',
#  '(주)엘피케이로보틱스',
#  '(주)영현무역',
#  '(주)우성아이비',
#  '(주)원익테라세미콘',
#  '(주)웹솔루스',
#  '(주)유디피',
#  '(주)유쎌',
#  '(주)이푸른',
#  '(주)인터파크',
#  '(주)인프라웨어테크놀러지',
#  '(주)자비스',
#  '(주)제이에스피브이',
#  '(주)주노콜렉션',
#  '(주)지성이씨에스',
#  '(주)카이노스메드',
#  '(주)카카오',
#  '(주)카카오엠',
#  '(주)캐로스',
#  '(주)케미메디',
#  '(주)태경피엔에스',
#  '(주)테라텍',
#  '(주)티씨엠생명과학',
#  '(주)티에스트릴리온',
#  '(주)판타지오',
#  '(주)포스코케미칼',
#  '(주)피엠디아카데미',
#  '(주)피엠에스',
#  '(주)하림홀딩스',
#  '(주)한국비엔씨',
#  '(주)한진피앤씨',
#  '(주)한컴지엠디',
#  '(주)힘스인터내셔널',
#  '나무기술(주)',
#  '디와이엘엔제이(주)',
#  '삼목강업(주)',
#  '세미텍(주)',
#  '세신버팔로(주)',
#  '세종머티리얼즈(주)',
#  '소프트캠프(주)',
#  '스탠다드펌(주)',
#  '씨제이이앤엠(주)',
#  '아스팩오일(주)',
# ...

# %%
df['[제조]유형자산증가율']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#        ...
# 798    -6.43
# 799     0.36
# 800     1.36
# 801    17.07
# 802    16.36
# Name: [제조]유형자산증가율, Length: 803, dtype: float64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '회사명', '거래소코드', '회계년도', '상장일', '상장폐지일', '삭제여부', '사유',
#        '산업명', '소속코드', '[제조]매출액증가율', '[제조]유형자산증가율', '[제조]비유동자산증가율',
#        '[제조]총자본증가율', '[제조]자기자본증가율', '[제조]유동자산증가율', '[제조]순이익증가율', '[제조]재고자산증가율',
#        '[제조]매출액총이익률', '[제조]매출액순이익률', '[제조]총자본사업이익률', '[제조]총자본순이익률',
#        '[제조]자기자본순이익률', '[제조]1주당순이익', '[제조]1주당매출액', '[제조]총자본회전률', '[제조]자기자본회전률',
#        '[제조]비유동자산회전률', '[제조]재고자산회전률', '[제조]매출채권회전률', '[제조]매입채무회전률',
#        '[제조]매입채무회전기간', '[제조]재고자산회전기간', '[제조]매출채권회전기간', '[제조]1회전기간',
#        '[제조]운전자본회전률', '[제조]순운전자본회전률', '[제조]유동자산회전률', '[제조]당좌자산회전률', '[제조]유동비율',
#        '[제조]당좌비율', '[제조]현금비율', '[제조]부채비율', '[제조]순운전자본비율', '[제조]자기자본배율',
#        '[제조]비유동비율', '[제조]유동자산구성비율', '[제조]자기자본구성비율', '[제조]부가가치', '[제조]총자본투자효율',
#        '[제조]설비투자효율', '[제조]기계투자효율', '[제조]부가가치율', '[제조]노동소득분배율', '[제조]자본분배율',
#        '[제조]이윤분배율', '[제조]유형자산회전율', '[제조]이자보상배율(이자비용)'],
#       dtype='object')

# %%
df = df.dropna(subset=['[제조]매출액증가율'])
df
# Out:
#      Unnamed: 0        회사명  거래소코드    회계년도         상장일       상장폐지일 삭제여부  \
# 5           252  (주)나노트로닉스  10670  Dec-11  1996-05-14  2014-04-11  NaN
# 6           253  (주)나노트로닉스  10670  Dec-12  1996-05-14  2014-04-11  NaN
# 9           363    (주)네오퍼플  28090  Dec-11  1996-11-29  2013-05-03  NaN
# 10          364    (주)네오퍼플  28090  Dec-12  1996-11-29  2013-05-03  NaN
# 11          401     (주)넥스지  81970  Dec-11  2007-08-20  2018-10-11  NaN
# ..          ...        ...    ...     ...         ...         ...  ...
# 798       11158  현대정보기술(주)  26180  Dec-14  2000-08-08  2019-07-17   삭제
# 799       11159  현대정보기술(주)  26180  Dec-15  2000-08-08  2019-07-17   삭제
# 800       11160  현대정보기술(주)  26180  Dec-16  2000-08-08  2019-07-17   삭제
# 801       11161  현대정보기술(주)  26180  Dec-17  2000-08-08  2019-07-17   삭제
# 802       11162  현대정보기술(주)  26180  Dec-18  2000-08-08  2019-07-17   삭제
#
#                                                    사유  \
# 5    기업의 계속성 및 경영의 투명성 등을 종합적으로 고려하여 상장폐지기준에 해당한다고 결정
# ...

# %%
df_delete = df[df['삭제여부']=='삭제'].index
df= df.drop(df_delete)

# %%
df['회사명'].value_counts()
# Out:
# 에스케이씨솔믹스(주)    9
# (주)바이오빌        9
# (주)에스에프씨       9
# (주)에스마크        9
# (주)피앤텔         9
#               ..
# (주)비앤비성원       1
# 미리넷(주)         1
# 어울림정보기술(주)     1
# (주)퓨얼셀파워       1
# (주)인스프리트       1
# Name: 회사명, Length: 151, dtype: int64

# %%
df
# Out:
#      Unnamed: 0        회사명  거래소코드    회계년도         상장일       상장폐지일 삭제여부  \
# 5           252  (주)나노트로닉스  10670  Dec-11  1996-05-14  2014-04-11  NaN
# 6           253  (주)나노트로닉스  10670  Dec-12  1996-05-14  2014-04-11  NaN
# 9           363    (주)네오퍼플  28090  Dec-11  1996-11-29  2013-05-03  NaN
# 10          364    (주)네오퍼플  28090  Dec-12  1996-11-29  2013-05-03  NaN
# 11          401     (주)넥스지  81970  Dec-11  2007-08-20  2018-10-11  NaN
# ..          ...        ...    ...     ...         ...         ...  ...
# 788       11014    한솔신텍(주)  99660  Dec-13  2009-04-30  2018-07-09  NaN
# 789       11015    한솔신텍(주)  99660  Dec-14  2009-04-30  2018-07-09  NaN
# 790       11016    한솔신텍(주)  99660  Dec-15  2009-04-30  2018-07-09  NaN
# 791       11017    한솔신텍(주)  99660  Dec-16  2009-04-30  2018-07-09  NaN
# 792       11018    한솔신텍(주)  99660  Dec-17  2009-04-30  2018-07-09  NaN
#
#                                                    사유  \
# 5    기업의 계속성 및 경영의 투명성 등을 종합적으로 고려하여 상장폐지기준에 해당한다고 결정
# ...

# %%
df2 = pd.read_csv('./dataset/증가율수정데이터(성휘).csv', encoding='CP949')
df2
# Out:
#        Unnamed: 0       회사명  거래소코드     회계년도  매출액증가율(IFRS연결)  유형자산증가율(IFRS연결)  \
# 0               0  (주)CMG제약  58820  2010/12             NaN              NaN
# 1               1  (주)CMG제약  58820  2011/12       56.396905        -5.903938
# 2               2  (주)CMG제약  58820  2012/12       -8.429134        -4.123269
# 3               3  (주)CMG제약  58820  2013/12       25.510008        16.090388
# 4               4  (주)CMG제약  58820  2014/12       11.520576        74.304624
# ...           ...       ...    ...      ...             ...              ...
# 14947       14947   흥구석유(주)  24060  2016/12       -7.264247        -5.613254
# 14948       14948   흥구석유(주)  24060  2017/12        8.117096        -0.564858
# 14949       14949   흥구석유(주)  24060  2018/12        6.874950        -0.359378
# 14950       14950   흥구석유(주)  24060  2019/12       -9.349453        -7.003757
# 14951       14951   흥구석유(주)  24060  2020/12      -23.777328       -13.917204
#
# ...

# %%
for i in range(len(df2)):
    if df2['회사명'][i] in list:
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-0f9fcd125733> in <module>
#       1 for i in range(len(df2)):
#       2     if df2['회사명'][i] in list:
# ----> 3         df2['회사명'][i].drop(axis=0, inplace=True)
#
# AttributeError: 'str' object has no attribute 'drop'

# %%
df3 = pd.read_csv('./KOSDAQ/연결개별통합본.csv', encoding='CP949')

# %%
df3.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '상장일', '상장폐지일', '산업명', '소속코드', '[제조]매출액증가율',
#        '[제조]유형자산증가율', '[제조]비유동자산증가율', '[제조]총자본증가율', '[제조]자기자본증가율',
#        '[제조]유동자산증가율', '[제조]순이익증가율', '[제조]재고자산증가율', '[제조]매출액총이익률',
#        '[제조]매출액순이익률', '[제조]총자본사업이익률', '[제조]총자본순이익률', '[제조]자기자본순이익률',
#        '[제조]1주당순이익', '[제조]1주당매출액', '[제조]총자본회전률', '[제조]자기자본회전률', '[제조]비유동자산회전률',
#        '[제조]재고자산회전률', '[제조]매출채권회전률', '[제조]매입채무회전률', '[제조]매입채무회전기간',
#        '[제조]재고자산회전기간', '[제조]매출채권회전기간', '[제조]1회전기간', '[제조]운전자본회전률',
#        '[제조]순운전자본회전률', '[제조]유동자산회전률', '[제조]당좌자산회전률', '[제조]유동비율', '[제조]당좌비율',
#        '[제조]현금비율', '[제조]부채비율', '[제조]순운전자본비율', '[제조]자기자본배율', '[제조]비유동비율',
#        '[제조]유동자산구성비율', '[제조]자기자본구성비율', '[제조]부가가치', '[제조]총자본투자효율', '[제조]설비투자효율',
#        '[제조]기계투자효율', '[제조]부가가치율', '[제조]노동소득분배율', '[제조]자본분배율', '[제조]이윤분배율',
#        '[제조]유형자산회전율', '[제조]이자보상배율(이자비용)'],
#       dtype='object')

# %%
df3['[제조]매출액증가율'].dropna()
# Out:
# 0        56.40
# 1        -8.43
# 2        25.51
# 3        11.52
# 4        18.85
#          ...
# 11228    -7.26
# 11229     8.12
# 11230     6.87
# 11231    -9.35
# 11232   -23.78
# Name: [제조]매출액증가율, Length: 10871, dtype: float64

# %%
df3 = df3.dropna(subset=['[제조]매출액증가율'])

# %%
dfb = df5[df5['회사명'].isin(list_a)].index
df5 = df5.drop(dfb)

# %%
df5['회계년도'] = pd.to_datetime(df5['회계년도'])

# %%
dfy = df5[df5['회계년도'].dt.year == 2010].index
df5 = df5.drop(dfy)

# %%
df5
# Out:
#        Unnamed: 0       회사명  거래소코드       회계년도  매출액증가율(IFRS연결)  \
# 1               1  (주)CMG제약  58820 2011-12-01       56.396905
# 2               2  (주)CMG제약  58820 2012-12-01       -8.429134
# 3               3  (주)CMG제약  58820 2013-12-01       25.510008
# 4               4  (주)CMG제약  58820 2014-12-01       11.520576
# 5               5  (주)CMG제약  58820 2015-12-01       18.851969
# ...           ...       ...    ...        ...             ...
# 14947       14947   흥구석유(주)  24060 2016-12-01       -7.264247
# 14948       14948   흥구석유(주)  24060 2017-12-01        8.117096
# 14949       14949   흥구석유(주)  24060 2018-12-01        6.874950
# 14950       14950   흥구석유(주)  24060 2019-12-01       -9.349453
# 14951       14951   흥구석유(주)  24060 2020-12-01      -23.777328
#
#        유형자산증가율(IFRS연결)  재고자산증가율(IFRS연결)  비유동자산증가율(IFRS연결)  유동자산증가율(IFRS연결)  \
# 1            -5.903938        -1.425061        -12.890111        17.636025
# ...

# %%
df3.to_csv('./dataset/부도기업_부도사유제외(성휘).csv', encoding='CP949', index=False)

# %%
df3.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '상장일', '상장폐지일', '산업명', '소속코드', '[제조]매출액증가율',
#        '[제조]유형자산증가율', '[제조]비유동자산증가율', '[제조]총자본증가율', '[제조]자기자본증가율',
#        '[제조]유동자산증가율', '[제조]순이익증가율', '[제조]재고자산증가율', '[제조]매출액총이익률',
#        '[제조]매출액순이익률', '[제조]총자본사업이익률', '[제조]총자본순이익률', '[제조]자기자본순이익률',
#        '[제조]1주당순이익', '[제조]1주당매출액', '[제조]총자본회전률', '[제조]자기자본회전률', '[제조]비유동자산회전률',
#        '[제조]재고자산회전률', '[제조]매출채권회전률', '[제조]매입채무회전률', '[제조]매입채무회전기간',
#        '[제조]재고자산회전기간', '[제조]매출채권회전기간', '[제조]1회전기간', '[제조]운전자본회전률',
#        '[제조]순운전자본회전률', '[제조]유동자산회전률', '[제조]당좌자산회전률', '[제조]유동비율', '[제조]당좌비율',
#        '[제조]현금비율', '[제조]부채비율', '[제조]순운전자본비율', '[제조]자기자본배율', '[제조]비유동비율',
#        '[제조]유동자산구성비율', '[제조]자기자본구성비율', '[제조]부가가치', '[제조]총자본투자효율', '[제조]설비투자효율',
#        '[제조]기계투자효율', '[제조]부가가치율', '[제조]노동소득분배율', '[제조]자본분배율', '[제조]이윤분배율',
#        '[제조]유형자산회전율', '[제조]이자보상배율(이자비용)'],
#       dtype='object')
