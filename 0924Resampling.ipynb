# %%
import pandas as pd
import numpy as np
 
from scipy.stats import norm
from scipy import stats
from statsmodels.formula.api import ols
from scipy.stats import kstest

# %%
df = pd.read_csv('./dataset/label지정.csv', encoding='CP949')
normal = df[df['label']==1].index
df_n = df.drop(normal)

# %%
df2 = pd.read_csv('./dataset/D1_전체label(찐수정).csv', encoding='CP949')

# %%
df_n = df_n[['[제조]매출액증가율',
       '[제조]유형자산증가율', '[제조]비유동자산증가율', '[제조]총자본증가율', '[제조]자기자본증가율',
       '[제조]유동자산증가율', '[제조]순이익증가율', '[제조]재고자산증가율', '[제조]매출액총이익률',
       '[제조]매출액순이익률', '[제조]총자본사업이익률', '[제조]총자본순이익률', '[제조]자기자본순이익률',
       '[제조]1주당순이익', '[제조]1주당매출액', '[제조]총자본회전률', '[제조]자기자본회전률', '[제조]비유동자산회전률',
       '[제조]재고자산회전률', '[제조]매출채권회전률', '[제조]매입채무회전률', '[제조]매입채무회전기간',
       '[제조]재고자산회전기간', '[제조]매출채권회전기간', '[제조]1회전기간', '[제조]운전자본회전률',
       '[제조]순운전자본회전률', '[제조]유동자산회전률', '[제조]당좌자산회전률', '[제조]유동비율', '[제조]당좌비율',
       '[제조]현금비율', '[제조]부채비율', '[제조]순운전자본비율', '[제조]자기자본배율', '[제조]비유동비율',
       '[제조]유동자산구성비율', '[제조]자기자본구성비율', '[제조]부가가치', '[제조]총자본투자효율', '[제조]설비투자효율',
       '[제조]기계투자효율', '[제조]부가가치율', '[제조]노동소득분배율', '[제조]자본분배율', '[제조]이윤분배율',
       '[제조]유형자산회전율', '[제조]이자보상배율(이자비용)']]

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', '회사명', '거래소코드', '회계년도', '상장일', '상장폐지일',
#        '산업명', '소속코드', '[제조]매출액증가율(IFRS연결)', '[제조]유형자산증가율(IFRS연결)',
#        '[제조]비유동자산증가율(IFRS연결)', '[제조]총자본증가율(IFRS연결)', '[제조]자기자본증가율(IFRS연결)',
#        '[제조]유동자산증가율(IFRS연결)', '[제조]순이익증가율(IFRS연결)', '[제조]재고자산증가율(IFRS연결)',
#        '[제조]매출액총이익률(IFRS연결)', '[제조]매출액순이익률(IFRS연결)', '[제조]총자본사업이익률(IFRS연결)',
#        '[제조]총자본순이익률(IFRS연결)', '[제조]자기자본순이익률(IFRS연결)', '[제조]1주당순이익(IFRS연결)',
#        '[제조]1주당매출액(IFRS연결)', '[제조]총자본회전률(IFRS연결)', '[제조]자기자본회전률(IFRS연결)',
#        '[제조]비유동자산회전률(IFRS연결)', '[제조]재고자산회전률(IFRS연결)', '[제조]매출채권회전률(IFRS연결)',
#        '[제조]매입채무회전률(IFRS연결)', '[제조]매입채무회전기간(IFRS연결)', '[제조]재고자산회전기간(IFRS연결)',
#        '[제조]매출채권회전기간(IFRS연결)', '[제조]1회전기간(IFRS연결)', '[제조]운전자본회전률(IFRS연결)',
#        '[제조]순운전자본회전률(IFRS연결)', '[제조]유동자산회전률(IFRS연결)', '[제조]당좌자산회전률(IFRS연결)',
#        '[제조]유동비율(IFRS연결)', '[제조]당좌비율(IFRS연결)', '[제조]현금비율(IFRS연결)',
#        '[제조]부채비율(IFRS연결)', '[제조]순운전자본비율(IFRS연결)', '[제조]자기자본배율(IFRS연결)',
# ...

# %%
df2_n = df2[['[제조]매출액증가율(IFRS연결)', '[제조]유형자산증가율(IFRS연결)',
       '[제조]비유동자산증가율(IFRS연결)', '[제조]총자본증가율(IFRS연결)', '[제조]자기자본증가율(IFRS연결)',
       '[제조]유동자산증가율(IFRS연결)', '[제조]순이익증가율(IFRS연결)', '[제조]재고자산증가율(IFRS연결)',
       '[제조]매출액총이익률(IFRS연결)', '[제조]매출액순이익률(IFRS연결)', '[제조]총자본사업이익률(IFRS연결)',
       '[제조]총자본순이익률(IFRS연결)', '[제조]자기자본순이익률(IFRS연결)', '[제조]1주당순이익(IFRS연결)',
       '[제조]1주당매출액(IFRS연결)', '[제조]총자본회전률(IFRS연결)', '[제조]자기자본회전률(IFRS연결)',
       '[제조]비유동자산회전률(IFRS연결)', '[제조]재고자산회전률(IFRS연결)', '[제조]매출채권회전률(IFRS연결)',
       '[제조]매입채무회전률(IFRS연결)', '[제조]매입채무회전기간(IFRS연결)', '[제조]재고자산회전기간(IFRS연결)',
       '[제조]매출채권회전기간(IFRS연결)', '[제조]1회전기간(IFRS연결)', '[제조]운전자본회전률(IFRS연결)',
       '[제조]순운전자본회전률(IFRS연결)', '[제조]유동자산회전률(IFRS연결)', '[제조]당좌자산회전률(IFRS연결)',
       '[제조]유동비율(IFRS연결)', '[제조]당좌비율(IFRS연결)', '[제조]현금비율(IFRS연결)',
       '[제조]부채비율(IFRS연결)', '[제조]순운전자본비율(IFRS연결)', '[제조]자기자본배율(IFRS연결)',
       '[제조]비유동비율(IFRS연결)', '[제조]유동자산구성비율(IFRS연결)', '[제조]자기자본구성비율(IFRS연결)',
       '[제조]부가가치(IFRS연결)', '[제조]총자본투자효율(IFRS연결)', '[제조]설비투자효율(IFRS연결)',
       '[제조]기계투자효율(IFRS연결)', '[제조]부가가치율(IFRS연결)', '[제조]노동소득분배율(IFRS연결)',
       '[제조]자본분배율(IFRS연결)', '[제조]이윤분배율(IFRS연결)', '[제조]유형자산회전율(IFRS연결)',
       '[제조]이자보상배율(이자비용)(IFRS연결)']]

# %%
df2
# Out:
#       Unnamed: 0  Unnamed: 0.1        회사명  거래소코드        회계년도         상장일  \
# 0              0             0      CMG제약  58820  2011-12-01  2001-08-31
# 1              1             1      CMG제약  58820  2012-12-01  2001-08-31
# 2              2             2      CMG제약  58820  2013-12-01  2001-08-31
# 3              3             3      CMG제약  58820  2014-12-01  2001-08-31
# 4              4             4      CMG제약  58820  2015-12-01  2001-08-31
# ...          ...           ...        ...    ...         ...         ...
# 7525        7525          7535  에이아이비트(주)  39230  2016-12-01  2000-06-22
# 7526        7526          7536  에이아이비트(주)  39230  2017-12-01  2000-06-22
# 7527        7527          7537  에이아이비트(주)  39230  2018-12-01  2000-06-22
# 7528        7528          7538  에이아이비트(주)  39230  2019-12-01  2000-06-22
# 7529        7529          7539  에이아이비트(주)  39230  2020-12-01  2000-06-22
#
#            상장폐지일                                        산업명  소속코드  \
# ...

# %%
df_n.sample(n=10000, random_state=3)
# Out:
#        [제조]매출액증가율  [제조]유형자산증가율  [제조]비유동자산증가율  [제조]총자본증가율  [제조]자기자본증가율  \
# 89         -12.13        -1.09         -2.93       -0.56        -5.02
# 9600        17.80        16.38         -1.76        4.42         9.28
# 8347       -10.79       -19.60        -13.39       -4.78         6.91
# 7238         8.98        14.04          0.89        2.94         4.44
# 9362       -13.41       -21.09        -21.53      -20.05       264.80
# ...           ...          ...           ...         ...          ...
# 10227       -0.66        -0.76        -25.94       -0.62         0.72
# 1367       -52.26       -70.57        -24.16      -23.72       -25.51
# 6564         2.93        10.73         -0.07        2.16         5.53
# 8847       -13.39       -13.43         -4.95       -9.63       -13.41
# 9002        -3.13        11.39         23.35       11.75        17.64
#
#        [제조]유동자산증가율  [제조]순이익증가율  [제조]재고자산증가율  [제조]매출액총이익률  [제조]매출액순이익률  ...  \
# ...

# %%
list = [7000,6000,5000,4000, 2800, 2000]
df_nc = df2_n.columns.tolist()

# %%
df_n
# Out:
#        [제조]매출액증가율  [제조]유형자산증가율  [제조]비유동자산증가율  [제조]총자본증가율  [제조]자기자본증가율  \
# 0           56.40        -5.90        -12.89        1.98        -2.02
# 1           -8.43        -4.12        -16.43      109.15        75.17
# 2           25.51        16.09         77.05       -2.09        55.10
# 3           11.52        74.30         68.15        3.86         0.01
# 4           18.85        -5.37          1.66       -2.64        -4.48
# ...           ...          ...           ...         ...          ...
# 10657       -7.26        -5.61          0.11        1.39         1.39
# 10658        8.12        -0.56         -0.48        0.98         0.83
# 10659        6.87        -0.36         -2.09       -5.89         0.99
# 10660       -9.35        -7.00         -2.63       11.24         9.31
# 10661      -23.78       -13.92         -8.21        0.07         3.38
#
#        [제조]유동자산증가율  [제조]순이익증가율  [제조]재고자산증가율  [제조]매출액총이익률  [제조]매출액순이익률  ...  \
# ...

# %%
for i in list:
    df_k = df2_n.sample(n=i, random_state=3)
    for j in df_nc:
        a = stats.shapiro(df_k[j])
        p = a.pvalue
        if p < 0.1:
            print(i,j,p)
            continue
        else :
            print(i,p)
            break
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1681: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# 7000 [제조]매출액증가율(IFRS연결) 0.0
# 7000 [제조]유형자산증가율(IFRS연결) 0.0
# 7000 [제조]비유동자산증가율(IFRS연결) 0.0
# 7000 [제조]총자본증가율(IFRS연결) 0.0
# 7000 [제조]자기자본증가율(IFRS연결) 0.0
# 7000 [제조]유동자산증가율(IFRS연결) 0.0
# 7000 [제조]순이익증가율(IFRS연결) 0.0
# 7000 [제조]재고자산증가율(IFRS연결) 0.0
# 7000 [제조]매출액총이익률(IFRS연결) 0.0
# 7000 [제조]매출액순이익률(IFRS연결) 0.0
# 7000 [제조]총자본사업이익률(IFRS연결) 0.0
# 7000 [제조]총자본순이익률(IFRS연결) 0.0
# 7000 [제조]자기자본순이익률(IFRS연결) 0.0
# 7000 [제조]1주당순이익(IFRS연결) 0.0
# 7000 [제조]1주당매출액(IFRS연결) 0.0
# 7000 [제조]총자본회전률(IFRS연결) 0.0
# 7000 [제조]자기자본회전률(IFRS연결) 0.0
# 7000 [제조]비유동자산회전률(IFRS연결) 0.0
# 7000 [제조]재고자산회전률(IFRS연결) 0.0
# 7000 [제조]매출채권회전률(IFRS연결) 0.0
# 7000 [제조]매입채무회전률(IFRS연결) 0.0
# 7000 [제조]매입채무회전기간(IFRS연결) 0.0
# 7000 [제조]재고자산회전기간(IFRS연결) 0.0
# 7000 [제조]매출채권회전기간(IFRS연결) 0.0
# 7000 [제조]1회전기간(IFRS연결) 0.0
# 7000 [제조]운전자본회전률(IFRS연결) 0.0
# ...

# %%
for i in list:
    df_k = df2_n.sample(n=i, random_state=3)
    for j in df_nc:
        a = kstest(df_k[j], 'norm')
        p = a.pvalue
        if p < 0.1:
            print(i,j,p)
            continue
        else :
            print(i,p)
            break
# Out:
# 7000 [제조]매출액증가율(IFRS연결) 0.0
# 7000 [제조]유형자산증가율(IFRS연결) 0.0
# 7000 [제조]비유동자산증가율(IFRS연결) 0.0
# 7000 [제조]총자본증가율(IFRS연결) 0.0
# 7000 [제조]자기자본증가율(IFRS연결) 0.0
# 7000 [제조]유동자산증가율(IFRS연결) 0.0
# 7000 [제조]순이익증가율(IFRS연결) 0.0
# 7000 [제조]재고자산증가율(IFRS연결) 0.0
# 7000 [제조]매출액총이익률(IFRS연결) 0.0
# 7000 [제조]매출액순이익률(IFRS연결) 0.0
# 7000 [제조]총자본사업이익률(IFRS연결) 0.0
# 7000 [제조]총자본순이익률(IFRS연결) 0.0
# 7000 [제조]자기자본순이익률(IFRS연결) 0.0
# 7000 [제조]1주당순이익(IFRS연결) 0.0
# 7000 [제조]1주당매출액(IFRS연결) 0.0
# 7000 [제조]총자본회전률(IFRS연결) 0.0
# 7000 [제조]자기자본회전률(IFRS연결) 0.0
# 7000 [제조]비유동자산회전률(IFRS연결) 0.0
# 7000 [제조]재고자산회전률(IFRS연결) 0.0
# 7000 [제조]매출채권회전률(IFRS연결) 0.0
# 7000 [제조]매입채무회전률(IFRS연결) 0.0
# 7000 [제조]매입채무회전기간(IFRS연결) 0.0
# 7000 [제조]재고자산회전기간(IFRS연결) 0.0
# 7000 [제조]매출채권회전기간(IFRS연결) 0.0
# 7000 [제조]1회전기간(IFRS연결) 0.0
# 7000 [제조]운전자본회전률(IFRS연결) 0.0
# 7000 [제조]순운전자본회전률(IFRS연결) 0.0
# 7000 [제조]유동자산회전률(IFRS연결) 0.0
# 7000 [제조]당좌자산회전률(IFRS연결) 0.0
# 7000 [제조]유동비율(IFRS연결) 0.0
# 7000 [제조]당좌비율(IFRS연결) 0.0
# 7000 [제조]현금비율(IFRS연결) 0.0
# ...

# %%
i
# Out:
# 200

# %%
a =pd.DataFrame(a)

# %%
p
# Out:
# 2.6963990602150406e-53

# %%
kstest(df['[제조]유동자산증가율'], 'norm')
# Out:
# KstestResult(statistic=0.5520784258716935, pvalue=0.0)

# %%
from scipy.stats import kstest

#perform Kolmogorov-Smirnov test
b = kstest(df['[제조]유동자산증가율'], 'norm')

# %%
b.pvalue
# Out:
# 0.0

# %%
df12 = df_n.sample(n=4000,random_state=3)

# %%
kstest(df12['[제조]이자보상배율(이자비용)', 'norm')
# Out:
#   File "<ipython-input-81-aa5e60dd943a>", line 1
#     kstest(df12['[제조]이자보상배율(이자비용)', 'norm')
#                                           ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['
