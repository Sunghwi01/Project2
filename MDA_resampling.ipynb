# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./dataset/label지정.csv", encoding="cp949")
df[df['label']==1]
# Out:
#                       회사명   거래소코드                 회계년도         상장일  \
# 187                 (주)금빛   45890  2020-12-01 00:00:00  2005-11-28
# 245             (주)나노트로닉스   10670           2012-12-01  1996-05-14
# 348               (주)네오퍼플   28090           2012-12-01  1996-11-29
# 388                (주)넥스지   81970           2017-12-01  2007-08-20
# 424               (주)넷웨이브   47730           2011-12-01  2001-05-10
# ...                   ...     ...                  ...         ...
# 9784              잘만테크(주)   90120           2014-12-01  2007-05-22
# 9867              제이앤유글로벌   86200           2015-12-01  2006-06-07
# 9982   차이나그레이트스타인터내셔널리미티드  900040           2018-12-01  2009-05-29
# 9995      차이나하오란리사이클링유한공사  900090           2017-12-01  2010-02-05
# 10471             한솔신텍(주)   99660           2017-12-01  2009-04-30
#
#             상장폐지일                             산업명  소속코드  [제조]매출액증가율  \
# 187    2021-12-20                   전구 및 조명장치 제조업     4      -30.22
# ...

# %%
df.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '상장일', '상장폐지일', '산업명', '소속코드', '[제조]매출액증가율',
#        '[제조]유형자산증가율', '[제조]비유동자산증가율', '[제조]총자본증가율', '[제조]자기자본증가율',
#        '[제조]유동자산증가율', '[제조]순이익증가율', '[제조]재고자산증가율', '[제조]매출액총이익률',
#        '[제조]매출액순이익률', '[제조]총자본사업이익률', '[제조]총자본순이익률', '[제조]자기자본순이익률',
#        '[제조]1주당순이익', '[제조]1주당매출액', '[제조]총자본회전률', '[제조]자기자본회전률', '[제조]비유동자산회전률',
#        '[제조]재고자산회전률', '[제조]매출채권회전률', '[제조]매입채무회전률', '[제조]매입채무회전기간',
#        '[제조]재고자산회전기간', '[제조]매출채권회전기간', '[제조]1회전기간', '[제조]운전자본회전률',
#        '[제조]순운전자본회전률', '[제조]유동자산회전률', '[제조]당좌자산회전률', '[제조]유동비율', '[제조]당좌비율',
#        '[제조]현금비율', '[제조]부채비율', '[제조]순운전자본비율', '[제조]자기자본배율', '[제조]비유동비율',
#        '[제조]유동자산구성비율', '[제조]자기자본구성비율', '[제조]부가가치', '[제조]총자본투자효율', '[제조]설비투자효율',
#        '[제조]기계투자효율', '[제조]부가가치율', '[제조]노동소득분배율', '[제조]자본분배율', '[제조]이윤분배율',
#        '[제조]유형자산회전율', '[제조]이자보상배율(이자비용)', 'year', 'month', 'label'],
#       dtype='object')

# %%
df2 = df.copy()
# df2 = df2[df2['label'] == 0]
df2 = df2[['[제조]자기자본구성비율','[제조]순운전자본회전률','[제조]비유동자산회전률','[제조]총자본증가율','[제조]유동비율','[제조]비유동자산증가율','[제조]1주당매출액','[제조]총자본순이익률','[제조]부가가치율','year','label']]
df2
# Out:
#        [제조]자기자본구성비율  [제조]순운전자본회전률  [제조]비유동자산회전률  [제조]총자본증가율  [제조]유동비율  \
# 0             66.05          0.86          1.38        1.98    200.97
# 1             55.32          0.42          1.48      109.15    693.49
# 2             87.63          0.42          1.47       -2.09    694.71
# 3             84.39          0.56          0.96        3.86    324.58
# 4             82.80          0.75          0.90       -2.64    296.85
# ...             ...           ...           ...         ...       ...
# 10657         87.41          8.24          2.24        1.39    411.65
# 10658         87.29          7.20          2.42        0.98    177.50
# 10659         93.67          8.08          2.62       -5.89    329.17
# 10660         92.04          6.91          2.44       11.24    485.39
# 10661         95.08          4.00          1.96        0.07   1108.08
#
#        [제조]비유동자산증가율  [제조]1주당매출액  [제조]총자본순이익률  [제조]부가가치율  year  label
# ...

# %%
from scipy.stats.mstats import winsorize
import warnings
warnings.filterwarnings('ignore')

for col in df2.columns: 
     df2[col] = winsorize(df2[col], limits=0.01) # 범위. 양끝 0.01을 안쪽으로 넣어준다!)

df2.describe()
# Out:
#        [제조]자기자본구성비율  [제조]순운전자본회전률  [제조]비유동자산회전률    [제조]총자본증가율      [제조]유동비율  \
# count  10662.000000  10662.000000  10662.000000  10662.000000  10662.000000
# mean      59.628956      1.017944      2.341579     12.220262    297.460998
# std       20.883998      0.527619      2.274193     33.196715    348.914536
# min        8.930000      0.090000      0.120000    -47.320000     28.410000
# 25%       43.800000      0.650000      0.970000     -3.217500    107.592500
# 50%       60.290000      0.960000      1.670000      5.520000    175.140000
# 75%       77.047500      1.300000      2.847500     17.827500    331.600000
# max       95.200000      2.810000     14.140000    187.780000   2214.570000
#
#        [제조]비유동자산증가율     [제조]1주당매출액   [제조]총자본순이익률     [제조]부가가치율          year  \
# count  10662.000000   10662.000000  10662.000000  10662.000000  10662.000000
# mean      16.704286    9965.107211     -0.748504     18.035400   2015.869818
# ...

# %%
df_n = df2[df2['year'] < 2019]
df_i = df2[df2['year'] >= 2019]

# %%
from sklearn.model_selection import train_test_split
X = df_n.iloc[:,:-1]
y = df_n.iloc[:,-1]
# X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE

# %%
# from imblearn.over_sampling import *

# X_samp_1, y_samp_1 = RandomOverSampler(random_state=0,sampling_strategy=0.143).fit_resample(X, y)

# print('RS 적용 전 학습용 피처/레이블 데이터 세트: ', X.shape, y.shape)
# print('RS 적용 후 학습용 피처/레이블 데이터 세트: ', X_samp_1.shape, y_samp_1.shape)
# print('RS 적용 후 레이블 값 분포: \n', pd.Series(y_samp_1).value_counts())

# %%
from imblearn.under_sampling import *

X_samp, y_samp = SMOTE(random_state=0,sampling_strategy=0.25).fit_resample(X, y)

print('RS 적용 전 학습용 피처/레이블 데이터 세트: ', X.shape, y.shape)
print('RS 적용 후 학습용 피처/레이블 데이터 세트: ', X_samp.shape, y_samp.shape)
print('RS 적용 후 레이블 값 분포: \n', pd.Series(y_samp).value_counts())
# Out:
# RS 적용 전 학습용 피처/레이블 데이터 세트:  (8095, 10) (8095,)
# RS 적용 후 학습용 피처/레이블 데이터 세트:  (9946, 10) (9946,)
# RS 적용 후 레이블 값 분포:
#  0    7957
# 1    1989
# Name: label, dtype: int64

# %%
MDA_sampling_smote = pd.concat([X_samp,y_samp], axis=1)

# %%
MDA_sampling_smote.to_csv('./dataset/MDA_sampling_smote.csv' , encoding='CP949', index=False)

# %%
from imblearn.under_sampling import EditedNearestNeighbours

enn = EditedNearestNeighbours(n_neighbors = 274)

X_res, y_res = enn.fit_resample(X,y)

print('ENN적용 후 :', X_res.shape, y_res.shape)
print('ENN 적용 후 레이블 값 분포 : \n', pd.Series(y_res).value_counts())
# Out:
# ENN적용 후 : (691, 10) (691,)
# ENN 적용 후 레이블 값 분포 :
#  0    553
# 1    138
# Name: label, dtype: int64

# %%
MDA_sampling_ENN = pd.concat([X_res,y_res], axis=1)

# %%
MDA_sampling_ENN.to_csv('./dataset/MDA_sampling_ENN.csv', encoding='CP949', index=False)

# %%
# imbalanced-learn 패키지
from imblearn.combine import SMOTEENN

# SMOTE 객체 생성
smt = SMOTEENN(random_state=0,sampling_strategy=0.2867)

X_smtn,y_smtn = smt.fit_resample(X,y)

# 샘플링
print('SMOTEENN 적용 전 학습용 피처/레이블 데이터 세트: ', X.shape, y.shape)
print('SMOTEENN 적용 후 학습용 피처/레이블 데이터 세트: ', X_smtn.shape, y_smtn.shape)
print('SMOTEENN 적용 후 레이블 값 분포: \n', pd.Series(y_smtn).value_counts())
# Out:
# SMOTEENN 적용 전 학습용 피처/레이블 데이터 세트:  (8095, 10) (8095,)
# SMOTEENN 적용 후 학습용 피처/레이블 데이터 세트:  (8385, 10) (8385,)
# SMOTEENN 적용 후 레이블 값 분포:
#  0    6710
# 1    1675
# Name: label, dtype: int64

# %%
MDA_sampling_smotEEN = pd.concat([X_smtn,y_smtn], axis=1)

# %%
MDA_sampling_smotEEN.to_csv('./dataset/MDA_sampling_smotEEN.csv', encoding='CP949', index=False)
