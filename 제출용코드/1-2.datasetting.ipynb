# %%
import pandas as pd

# %% [markdown]
# ## 데이터 개수가 1인 기업 삭제
# - 중복수가 1인 데이터 제거

# %%
df_da = pd.read_csv('./dataset/1-1dataset.csv', encoding='CP949')

# %%
dele = df_da[df_da['중복']==1].index
df = df_da.drop(dele)

# %%
df
# Out:
#              회사명  거래소코드    회계년도         상장일       상장폐지일  \
# 0       (주)CMG제약  58820  Dec-11  2001-08-31         NaN
# 1       (주)CMG제약  58820  Dec-12  2001-08-31         NaN
# 2       (주)CMG제약  58820  Dec-13  2001-08-31         NaN
# 3       (주)CMG제약  58820  Dec-14  2001-08-31         NaN
# 4       (주)CMG제약  58820  Dec-15  2001-08-31         NaN
# ...          ...    ...     ...         ...         ...
# 11045  에이아이비트(주)  39230  16-Dec  2000-06-22  2021-10-06
# 11046  에이아이비트(주)  39230  17-Dec  2000-06-22  2021-10-06
# 11047  에이아이비트(주)  39230  18-Dec  2000-06-22  2021-10-06
# 11048  에이아이비트(주)  39230  19-Dec  2000-06-22  2021-10-06
# 11049  에이아이비트(주)  39230  20-Dec  2000-06-22  2021-10-06
#
#                                              산업명  소속코드  [제조]매출액증가율  \
# 0                               의료용 물질 및 의약품 제조업     5       56.40
# 1                               의료용 물질 및 의약품 제조업     5       -8.43
# 2                               의료용 물질 및 의약품 제조업     5       25.51
# ...

# %% [markdown]
# ## 증가율 0 값 , 이자보상배율 이상치 계산
# - 엑셀에서 교체

# %%
df1 = pd.read_csv('./dataset/이자보상배율최종.csv', encoding='CP949')

# %%
df1
# Out:
#             회사명  거래소코드        회계년도         상장일 상장폐지일                 산업명  \
# 0      (주)CMG제약  58820  2011-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 1      (주)CMG제약  58820  2012-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 2      (주)CMG제약  58820  2013-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 3      (주)CMG제약  58820  2014-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 4      (주)CMG제약  58820  2015-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# ...         ...    ...         ...         ...   ...                 ...
# 10647   흥구석유(주)  24060  2016-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10648   흥구석유(주)  24060  2017-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10649   흥구석유(주)  24060  2018-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10650   흥구석유(주)  24060  2019-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10651   흥구석유(주)  24060  2020-12-01  1994-12-07   NaN         도매 및 상품 중개업
#
#        소속코드  [제조]매출액증가율  [제조]유형자산증가율  [제조]비유동자산증가율  ...  [제조]기계투자효율  \
# ...

# %% [markdown]
# ## 최종 데이터
# - 정상기업 - 부도기업
# - 9956 - 696

# %%
df1
# Out:
#             회사명  거래소코드        회계년도         상장일 상장폐지일                 산업명  \
# 0      (주)CMG제약  58820  2011-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 1      (주)CMG제약  58820  2012-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 2      (주)CMG제약  58820  2013-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 3      (주)CMG제약  58820  2014-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 4      (주)CMG제약  58820  2015-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# ...         ...    ...         ...         ...   ...                 ...
# 10647   흥구석유(주)  24060  2016-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10648   흥구석유(주)  24060  2017-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10649   흥구석유(주)  24060  2018-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10650   흥구석유(주)  24060  2019-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10651   흥구석유(주)  24060  2020-12-01  1994-12-07   NaN         도매 및 상품 중개업
#
#        소속코드  [제조]매출액증가율  [제조]유형자산증가율  [제조]비유동자산증가율  ...  [제조]기계투자효율  \
# ...

# %%
len(df1[df1['label']==0]['회사명'].unique())
# Out:
# 1420

# %%
len(df1[df1['label']==1]['회사명'].unique())
# Out:
# 163

# %%
len(df1['회사명'].unique())
# Out:
# 1461
