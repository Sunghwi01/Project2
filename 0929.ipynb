# %%
import pandas as pd

# %%
df = pd.read_csv('./dataset/윈저데이터셋.csv', encoding='CP949')
df1 = pd.read_csv('./dataset/이자보상배율최종.csv', encoding='CP949')

# %%
df
# Out:
#             회사명  거래소코드        회계년도         상장일 상장폐지일                 산업명  \
# 0      (주)CMG제약  58820  2011-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 1      (주)CMG제약  58820  2012-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 2      (주)CMG제약  58820  2013-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 3      (주)CMG제약  58820  2014-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 4      (주)CMG제약  58820  2015-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# ...         ...    ...         ...         ...   ...                 ...
# 10649   흥구석유(주)  24060  2016-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10650   흥구석유(주)  24060  2017-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10651   흥구석유(주)  24060  2018-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10652   흥구석유(주)  24060  2019-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10653   흥구석유(주)  24060  2020-12-01  1994-12-07   NaN         도매 및 상품 중개업
#
#        소속코드  [제조]매출액증가율  [제조]유형자산증가율  [제조]비유동자산증가율  ...  [제조]기계투자효율  \
# ...

# %%
df = df.groupby('거래소코드')['회사명'].apply(list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-ca2c8a27df5f> in <module>
# ----> 1 df = df.groupby('거래소코드')['회사명'].apply(list)
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in apply(self, func, *args, **kwargs)
#     219     )
#     220     def apply(self, func, *args, **kwargs):
# --> 221         return super().apply(func, *args, **kwargs)
#     222
#     223     @doc(_agg_template, examples=_agg_examples_doc, klass="Series")
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     865     def apply(self, func, *args, **kwargs):
#     866
# --> 867         func = self._is_builtin_func(func)
#     868
#     869         # this is needed so we don't try and wrap strings. If we could
#
# ...

# %%
df = pd.DataFrame(df)

# %%
df.reset_index( inplace=True)

# %%
for i in df.index:
    a = len(df.loc[i,'회사명'])
    print(a)
# Out:
# 8
# 7
# 6
# 10
# 8
# 8
# 8
# 10
# 8
# 8
# 6
# 11
# 5
# 5
# 7
# 8
# 6
# 8
# 8
# 6
# 8
# 15
# 9
# 7
# 8
# 8
# 5
# 7
# 8
# 7
# 9
# 6
# 8
# 6
# 9
# 9
# 7
# 6
# 7
# 7
# 10
# 8
# 7
# 6
# 7
# 7
# 13
# 7
# 6
# 8
# 6
# 13
# 8
# 14
# 6
# 8
# 5
# 7
# 7
# 7
# 6
# 8
# 6
# 9
# 8
# 9
# 7
# 8
# 6
# 6
# 6
# 6
# 10
# 7
# 6
# 5
# 9
# 8
# 7
# 5
# 7
# 7
# 7
# 9
# 11
# 7
# 8
# 5
# 5
# 8
# 8
# 7
# 7
# 8
# 7
# 10
# 8
# 9
# 8
# 9
# 7
# 10
# 10
# 9
# 9
# 7
# 8
# 7
# 8
# 10
# 8
# 7
# 7
# 8
# 8
# 6
# 9
# 9
# 10
# 10
# 12
# 5
# 6
# 10
# 10
# 7
# 6
# 6
# 6
# 9
# 6
# 8
# 8
# 9
# 11
# 7
# 9
# 7
# 7
# 5
# 7
# 7
# 7
# 6
# 8
# 10
# 10
# 8
# 7
# 7
# 8
# 5
# 6
# 7
# 8
# 7
# 6
# 8
# 5
# 13
# 7
# 8
# 5
# 5
# 7
# 9
# 7
# 7
# 7
# 7
# 6
# 7
# 11
# 8
# 6
# 10
# 5
# 7
# 6
# 6
# 9
# 10
# 7
# 10
# 12
# 10
# 7
# 9
# 6
# 7
# 6
# 8
# 7
# 7
# 7
# 10
# 6
# 6
# 10
# 9
# 6
# 5
# 8
# 11
# 6
# 8
# 7
# 9
# 6
# 6
# 8
# 9
# 8
# 9
# 5
# 10
# 6
# 10
# 7
# 7
# 9
# 8
# 12
# 7
# 9
# 9
# 9
# 5
# 5
# 9
# 9
# 8
# 5
# 6
# 7
# 8
# 7
# 7
# 5
# 6
# 13
# ...

# %%
df['거래소코드'][0][-1]
# Out:
# 58820

# %%
df_list = []
for i in range(0,1461):
    a = df['거래소코드'][i][-1]
    b = df['거래소코드'][i][0]
    if df['거래소코드'][i][0] != df['거래소코드'][i][-1]:
        df_list.append(a)

# %%
df_list
# Out:
# [252500, 277410, 256630, 222080]

# %%
df_d = df1[df1['거래소코드'] == 144630].index
df1 =df1.drop(df_d)

# %%
df1[df1['거래소코드']==222080]
# Out:
#            회사명   거래소코드        회계년도         상장일       상장폐지일               산업명  \
# 8779  씨아이에스(주)  222080  2015-12-01  2015-09-02  2017-01-20             기타금융업
# 8781  씨아이에스(주)  222080  2018-12-01  2015-09-02         NaN    기타 기계 및 장비 제조업
# 8782  씨아이에스(주)  222080  2019-12-01  2015-09-02         NaN    기타 기계 및 장비 제조업
# 8783  씨아이에스(주)  222080  2020-12-01  2015-09-02         NaN    기타 기계 및 장비 제조업
#
#       소속코드  [제조]매출액증가율  [제조]유형자산증가율  [제조]비유동자산증가율  ...  [제조]기계투자효율  [제조]부가가치율  \
# 8779     5       24.15        25.49         25.35  ...      225.48      37.67
# 8781     5       66.89       102.37         95.12  ...    -3017.98      -5.21
# 8782     5      134.24        11.34          5.41  ...     8257.53      25.46
# 8783     5       17.41        54.44         48.19  ...     1162.65       6.65
#
#       [제조]노동소득분배율  [제조]자본분배율  [제조]이윤분배율  [제조]유형자산회전율  [제조]이자보상배율(이자비용)  year  \
# 8779        66.02      33.98      29.22         1.35             20.10  2015
# ...

# %%
df1[df1['회사명']=='씨아이에스(주)']
# Out:
#            회사명   거래소코드        회계년도         상장일       상장폐지일               산업명  \
# 8778  씨아이에스(주)  144630  2014-12-01  2014-04-25  2017-01-20    기타 기계 및 장비 제조업
# 8779  씨아이에스(주)  222080  2015-12-01  2015-09-02  2017-01-20             기타금융업
# 8780  씨아이에스(주)  144630  2015-12-01  2014-04-25  2017-01-20    기타 기계 및 장비 제조업
# 8781  씨아이에스(주)  222080  2018-12-01  2015-09-02         NaN    기타 기계 및 장비 제조업
# 8782  씨아이에스(주)  222080  2019-12-01  2015-09-02         NaN    기타 기계 및 장비 제조업
# 8783  씨아이에스(주)  222080  2020-12-01  2015-09-02         NaN    기타 기계 및 장비 제조업
#
#       소속코드  [제조]매출액증가율  [제조]유형자산증가율  [제조]비유동자산증가율  ...  [제조]기계투자효율  [제조]부가가치율  \
# 8778     4      -46.77        -2.20          0.78  ...     4745.48      22.43
# 8779     5       24.15        25.49         25.35  ...      225.48      37.67
# 8780     4       24.15        25.50         24.57  ...      224.81      37.56
# 8781     5       66.89       102.37         95.12  ...    -3017.98      -5.21
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.to_csv('./dataset/윈저데이터셋.csv', encoding='CP949', index=False)

# %%
df1.to_csv('./dataset/이자보상배율최종.csv', encoding='CP949', index=False)

# %%
df1
# Out:
#             회사명  거래소코드        회계년도         상장일 상장폐지일                 산업명  \
# 0      (주)CMG제약  58820  2011-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 1      (주)CMG제약  58820  2012-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 2      (주)CMG제약  58820  2013-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 3      (주)CMG제약  58820  2014-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 4      (주)CMG제약  58820  2015-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# ...         ...    ...         ...         ...   ...                 ...
# 10657   흥구석유(주)  24060  2016-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10658   흥구석유(주)  24060  2017-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10659   흥구석유(주)  24060  2018-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10660   흥구석유(주)  24060  2019-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10661   흥구석유(주)  24060  2020-12-01  1994-12-07   NaN         도매 및 상품 중개업
#
#        소속코드  [제조]매출액증가율  [제조]유형자산증가율  [제조]비유동자산증가율  ...  [제조]기계투자효율  \
# ...

# %%
df
# Out:
#             회사명  거래소코드        회계년도         상장일 상장폐지일                 산업명  \
# 0      (주)CMG제약  58820  2011-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 1      (주)CMG제약  58820  2012-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 2      (주)CMG제약  58820  2013-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 3      (주)CMG제약  58820  2014-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# 4      (주)CMG제약  58820  2015-12-01  2001-08-31   NaN    의료용 물질 및 의약품 제조업
# ...         ...    ...         ...         ...   ...                 ...
# 10649   흥구석유(주)  24060  2016-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10650   흥구석유(주)  24060  2017-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10651   흥구석유(주)  24060  2018-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10652   흥구석유(주)  24060  2019-12-01  1994-12-07   NaN         도매 및 상품 중개업
# 10653   흥구석유(주)  24060  2020-12-01  1994-12-07   NaN         도매 및 상품 중개업
#
#        소속코드  [제조]매출액증가율  [제조]유형자산증가율  [제조]비유동자산증가율  ...  [제조]기계투자효율  \
# ...
