# %%
import matplotlib.pyplot as plt
import seaborn as sns

penguin = sns.load_dataset('penguins')
penguin
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

penguin = sns.load_dataset('penguins')

marker = {"Torgersen":'o', "Biscoe":'s', "Dream":'+'}
color = {"Torgersen":'red', "Biscoe":'blue', "Dream":'green'}

plt.figure(figsize=(20,5))
grouped = penguin.groupby('island')
for i, items in grouped:
    plt.scatter('bill_length_mm', 'bill_depth_mm', data=items, s=9, label=i, marker=marker[i], c=color[i])
    
plt.title('Bill Size by Island', fontsize=14)
plt.xlabel('length', fontsize=12)
plt.ylabel('depth', fontsize=12)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

penguin = sns.load_dataset('penguins')

plt.figure(figsize=(20,5))
plt.scatter('bill_length_mm', 'bill_depth_mm', data=penguin, s=9, cmap='Reds', c='body_mass_g')
plt.title('Bill Size by Island', fontsize=14)
plt.xlabel('length', fontsize=12)
plt.ylabel('depth', fontsize=12)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

penguin = sns.load_dataset('penguins')
plt.figure(figsize=(20,5))
sns.scatterplot(x='bill_length_mm', y='bill_depth_mm', hue='island', style='island', s=50, data=penguin)
plt.show()

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

penguin = sns.load_dataset('penguins')

plt.figure(figsize=(20,5))
ax = sns.scatterplot(x='bill_length_mm', y='bill_depth_mm', hue='body_mass_g', palette='viridis', s=50, data=penguin)

norm = plt.Normalize(penguin['body_mass_g'].min(), penguin['body_mass_g'].max())
sm = plt.cm.ScalarMappable(cmap="viridis", norm=norm)
sm.set_array([])

ax.get_legend().remove()
ax.figure.colorbar(sm)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
iris=pd.read_csv("iris_data.csv",index_col=0)
n=150
x = np.random.rand(n)
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# plt.scatter(x,iris["sepal_length"])
# plt.scatter(x,iris["sepal_width"])
# plt.scatter(x,iris["petal_length"])
plt.plot(x,iris["petal_width"] ,'o', markersize=10, c='#FF5733')
plt.scatter(x,iris["petal_width"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
grouped=iris.groupby('species')

for i,items in grouped:
    plt.scatter("sepal_length","petal_length",data=items)
    print(i)
    # print(items)
plt.xlabel("sepal_length",fontsize=20)
plt.ylabel("petal_length",fontsize=20)
plt.title("종류별 길이")
# Out:
# setosa
# versicolor
# virginica
# Text(0.5, 1.0, '종류별 길이')
# c:\Users\jangd\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\jangd\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47448 (\N{HANGUL SYLLABLE RYU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\jangd\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\jangd\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
