# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()

# %% [markdown]
# #### countercolock

# %%
plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False) # counter clock은 시계 방향 순서로 부채꼴 영역이 표시됨
plt.show()

# %% [markdown]
# ### explode를 통해서 중심에서 벗어나는 정도 설정

# %%
explode = [0, 0.10, 0, 0.10]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.show()

# %% [markdown]
# ## colors를 통해서 색깔 설정

# %%
explode = [0.05, 0.05, 0.05, 0.05]
colors = ['silver', 'gold', 'whitesmoke', 'lightgray']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()

# %% [markdown]
# ### wedgerprops를 설정을 통해 도넛 모양 만들기

# %%
wedgeprops={'width': 0.9, 'edgecolor': 'w', 'linewidth': 3}  ## width는 가운데를 제외한 너비, edgecolor는 테두리 색, linewidth는 선 굵기
plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()

# %% [markdown]
# # 실습

# %%
import pandas as pd

# %%
tips=pd.read_csv("팁목록.csv",index_col=0)
tips["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
tips["day"].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
wedgeprops={'width':0.8,'edgecolor':'y','linewidth':4}

# %%
plt.pie(tips["day"].value_counts(), labels=['Sat','Sun', 'Thur', 'Fri'], autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()
