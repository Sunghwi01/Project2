# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
os.listdir('./dataset')
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
files = os.listdir('./dataset')
files
# Out:
# ['1주당매출액데이터.csv',
#  '노동소득분배율데이터.csv',
#  '매출채권회전률데이터.csv',
#  '범주혼합.csv',
#  '비유동자산회전률데이터.csv',
#  '수익성범주.csv',
#  '순운전자본회전률데이터.csv',
#  '안정성범주.csv',
#  '이자보상배율데이터.csv',
#  '자기자본배율데이터.csv',
#  '총자본사업이익률데이터.csv',
#  '총자본증가율데이터.csv',
#  '투자전략3.csv',
#  '현금비율데이터.csv',
#  '활동성범주.csv']

# %%
files[1].split('.')[0]
# Out:
# '노동소득분배율데이터'

# %%
df_1 = pd.read_csv('./dataset/1주당매출액데이터.csv', encoding='CP949')

# %%
for i in files:
     globals()[i.split('.')[0]] = pd.read_csv(f'./dataset/{i}', encoding='CP949')

# %%
df_no = 노동소득분배율데이터
df_mae = 매출채권회전률데이터
df_be = 비유동자산회전률데이터
df_soon = 순운전자본회전률데이터
df_i = 이자보상배율데이터
df_ja = 자기자본배율데이터
df_chongsa = 총자본사업이익률데이터
df_chongja = 총자본증가율데이터
df_soo = 수익성범주
df_hwal=활동성범주
df_an = 안정성범주
df_hyun = 현금비율데이터
df_bum = 범주혼합
df_to = 투자전략3

# %%
안정성범주
# Out:
#             투자일자  일일수익률(%)    누적수익률(%)  연누적수익률(%)   코스닥종가  코스닥수익률(%)  \
# 0     2011-04-04  0.906662    0.906662   0.906662  534.90   0.533774
# 1     2011-04-05  0.583637    1.495591   1.495591  537.66   0.515984
# 2     2011-04-06 -1.110946    0.368030   0.368030  533.98  -0.684447
# 3     2011-04-07  0.744100    1.114868   1.114868  534.97   0.185400
# 4     2011-04-08  0.278906    1.396883   1.396883  534.20  -0.143933
# ...          ...       ...         ...        ...     ...        ...
# 2448  2021-03-25 -0.324460  572.048178  87.602017  954.99   0.122665
# 2449  2021-03-26 -0.194407  570.741669  87.237306  956.70   0.179059
# 2450  2021-03-29 -0.284014  568.836671  86.705526  954.10  -0.271768
# 2451  2021-03-30  0.479479  572.043602  87.600740  958.06   0.415051
# 2452  2021-03-31  0.419489  574.862752  88.387704  956.17  -0.197274
#
#       코스닥누적수익률(%)  코스닥연누적수익률(%)  투자연차
# 0        0.533774      0.533774   1.0
# 1        1.052513      1.052513   1.0
# ...

# %%
범주혼합
# Out:
#             투자일자  일일수익률(%)    누적수익률(%)  연누적수익률(%)   코스닥종가  코스닥수익률(%)  \
# 0     2011-04-04 -0.355076   -0.355076  -0.355076  534.90   0.533774
# 1     2011-04-05  0.089691   -0.265703  -0.265703  537.66   0.515984
# 2     2011-04-06 -0.095384   -0.360834  -0.360834  533.98  -0.684447
# 3     2011-04-07  0.104232   -0.256978  -0.256978  534.97   0.185400
# 4     2011-04-08 -0.355504   -0.611568  -0.611568  534.20  -0.143933
# ...          ...       ...         ...        ...     ...        ...
# 2448  2021-03-25 -0.054217  184.394454  96.471059  954.99   0.122665
# 2449  2021-03-26 -0.000226  184.393810  96.470614  956.70   0.179059
# 2450  2021-03-29 -0.076579  184.176023  96.320159  954.10  -0.271768
# 2451  2021-03-30 -0.046577  184.043662  96.228718  958.06   0.415051
# 2452  2021-03-31  0.480351  185.408069  97.171305  956.17  -0.197274
#
#       코스닥누적수익률(%)  코스닥연누적수익률(%)  투자연차
# 0        0.533774      0.533774   1.0
# 1        1.052513      1.052513   1.0
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(df_mae['투자일자'],df_chongsa['누적수익률(%)'],label="총자본사업이익율누적수익률")
plt.plot(df_mae['투자일자'],df_chongja['누적수익률(%)'],label="총자본증가율누적수익률")
plt.plot(df_mae['투자일자'],df_i['누적수익률(%)'],label="이자보상배율누적수익률")
plt.plot(df_mae['투자일자'],df_be['누적수익률(%)'],label="1주당매출액누적수익률")
plt.plot(df_mae['투자일자'],df_soon['누적수익률(%)'],label="순운전자본회전률누적수익률")
plt.plot(df_mae['투자일자'],df_hyun['누적수익률(%)'],label="현금비율누적수익률")
plt.plot(df_mae['투자일자'],df_ja['누적수익률(%)'],label="자기자본배율누적수익률")
plt.plot(df_mae['투자일자'],df_mae['누적수익률(%)'],label="비유동자산회전률누적수익률")
plt.plot(df_mae['투자일자'],df_no['누적수익률(%)'],label="노동소득분배율누적수익률")
plt.plot(df_mae['투자일자'],df_mae['코스닥연누적수익률(%)'],label="코스닥연누적수익률")
plt.legend(fontsize=16)
plt.xticks([0,249,495,741,984,1231,1478,1719,1960,2208,2452], rotation=45, fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(df_an['투자일자'],df_soo['누적수익률(%)'],label="수익성")
plt.plot(df_an['투자일자'],df_chongja['누적수익률(%)'],label="성장성")
plt.plot(df_an['투자일자'],df_hwal['누적수익률(%)'],label="활동성")
plt.plot(df_an['투자일자'],df_an['누적수익률(%)'],label="안정성")
plt.plot(df_an['투자일자'],df_no['누적수익률(%)'],label="생산성")
plt.plot(df_mae['투자일자'],df_mae['코스닥연누적수익률(%)'],label="코스닥연누적수익률")
plt.legend(fontsize=16)
plt.xticks([0,249,495,741,984,1231,1478,1719,1960,2208,2452], rotation=45, fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(df_an['투자일자'],df_soo['누적수익률(%)'],label="수익성")
plt.plot(df_an['투자일자'],df_chongja['누적수익률(%)'],label="성장성")
plt.plot(df_an['투자일자'],df_hwal['누적수익률(%)'],label="활동성")
plt.plot(df_an['투자일자'],df_an['누적수익률(%)'],label="안정성")
plt.plot(df_an['투자일자'],df_bum['누적수익률(%)'],label="범주혼합")
plt.plot(df_an['투자일자'],df_mae['코스닥연누적수익률(%)'],label="코스닥연누적수익률")
plt.legend(fontsize=16)
plt.xticks([0,249,495,741,984,1231,1478,1719,1960,2208,2452], rotation=45, fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(df_an['투자일자'],df_to['누적수익률(%)'],label="투자전략3")
plt.plot(df_an['투자일자'],df_soo['누적수익률(%)'],label="수익성")
plt.plot(df_an['투자일자'],df_bum['누적수익률(%)'],label="범주혼합")
plt.plot(df_an['투자일자'],df_chongja['누적수익률(%)'],label="성장성")
plt.plot(df_an['투자일자'],df_hwal['누적수익률(%)'],label="활동성")
plt.plot(df_an['투자일자'],df_an['누적수익률(%)'],label="안정성")
plt.plot(df_an['투자일자'],df_bum['누적수익률(%)'],label="범주혼합")
plt.plot(df_an['투자일자'],df_mae['코스닥연누적수익률(%)'],label="코스닥연누적수익률")
plt.legend(fontsize=16)
plt.xticks([0,249,495,741,984,1231,1478,1719,1960,2208,2452], rotation=45, fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %%
df_list = [df_1,df_to,df_an,df_be,df_bum,df_chongja,df_chongsa,df_hwal,df_hyun,df_i,df_ja,df_mae,df_no,df_soo,df_soon]

# %%
df_bum
# Out:
#             투자일자  일일수익률(%)    누적수익률(%)  연누적수익률(%)   코스닥종가  코스닥수익률(%)  \
# 0     2011-04-04 -0.355076   -0.355076  -0.355076  534.90   0.533774
# 1     2011-04-05  0.089691   -0.265703  -0.265703  537.66   0.515984
# 2     2011-04-06 -0.095384   -0.360834  -0.360834  533.98  -0.684447
# 3     2011-04-07  0.104232   -0.256978  -0.256978  534.97   0.185400
# 4     2011-04-08 -0.355504   -0.611568  -0.611568  534.20  -0.143933
# ...          ...       ...         ...        ...     ...        ...
# 2448  2021-03-25 -0.054217  184.394454  96.471059  954.99   0.122665
# 2449  2021-03-26 -0.000226  184.393810  96.470614  956.70   0.179059
# 2450  2021-03-29 -0.076579  184.176023  96.320159  954.10  -0.271768
# 2451  2021-03-30 -0.046577  184.043662  96.228718  958.06   0.415051
# 2452  2021-03-31  0.480351  185.408069  97.171305  956.17  -0.197274
#
#       코스닥누적수익률(%)  코스닥연누적수익률(%)  투자연차
# 0        0.533774      0.533774   1.0
# 1        1.052513      1.052513   1.0
# ...

# %%
df_list[1]
# Out:
#             투자일자  일일수익률(%)     누적수익률(%)   연누적수익률(%)   코스닥종가  코스닥수익률(%)  \
# 0     2011-04-04  1.142676     1.142676    1.142676  534.90   0.533774
# 1     2011-04-05 -0.041291     1.100913    1.100913  537.66   0.515984
# 2     2011-04-06  0.071781     1.173484    1.173484  533.98  -0.684447
# 3     2011-04-07  2.191835     3.391040    3.391040  534.97   0.185400
# 4     2011-04-08 -0.336044     3.043601    3.043601  534.20  -0.143933
# ...          ...       ...          ...         ...     ...        ...
# 2448  2021-03-25 -1.259296  3595.937100  143.506880  954.99   0.122665
# 2449  2021-03-26  0.928410  3630.250548  145.767622  956.70   0.179059
# 2450  2021-03-29 -1.036696  3591.579176  143.219758  954.10  -0.271768
# 2451  2021-03-30  0.303004  3602.764819  143.956724  958.06   0.415051
# 2452  2021-03-31 -0.245930  3593.658599  143.356761  956.17  -0.197274
#
#       코스닥누적수익률(%)  코스닥연누적수익률(%)  투자연차
# 0        0.533774      0.533774   1.0
# ...

# %%
for i in range(len(df_list)):
    df_list[i] = df_list[i][df_list[i]['투자연차']!=10]

# %%
df_1_2019 = df_list[0]
df_to_2019 = df_list[1]
df_an_2019 = df_list[2]
df_be_2019 = df_list[3]
df_bum_2019 = df_list[4]
df_chongja_2019= df_list[5]
df_chongsa_2019= df_list[6]
df_hwal_2019= df_list[7]
df_hyun_2019= df_list[8]
df_i_2019= df_list[9]
df_ja_2019= df_list[10]
df_mae_2019= df_list[11]
df_no_2019= df_list[12]
df_soo_2019= df_list[13]
df_soon_2019= df_list[14]

# %%
df_bum_2019
# Out:
#             투자일자  일일수익률(%)   누적수익률(%)  연누적수익률(%)   코스닥종가  코스닥수익률(%)  \
# 0     2011-04-04 -0.355076  -0.355076  -0.355076  534.90   0.533774
# 1     2011-04-05  0.089691  -0.265703  -0.265703  537.66   0.515984
# 2     2011-04-06 -0.095384  -0.360834  -0.360834  533.98  -0.684447
# 3     2011-04-07  0.104232  -0.256978  -0.256978  534.97   0.185400
# 4     2011-04-08 -0.355504  -0.611568  -0.611568  534.20  -0.143933
# ...          ...       ...        ...        ...     ...        ...
# 2203  2020-03-25  4.231620  35.547945 -19.806320  505.68   5.262281
# 2204  2020-03-26  0.443332  36.148872 -19.450796  516.61   2.161446
# 2205  2020-03-27  0.601248  36.967464 -18.966496  522.83   1.204003
# 2206  2020-03-30  2.247313  40.045552 -17.145419  542.11   3.687623
# 2207  2020-03-31  3.360170  44.751321 -14.361364  569.07   4.973160
#
#       코스닥누적수익률(%)  코스닥연누적수익률(%)  투자연차
# 0        0.533774      0.533774   1.0
# 1        1.052513      1.052513   1.0
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(df_mae_2019['투자일자'],df_chongsa_2019['누적수익률(%)'],label="총자본사업이익율누적수익률")
plt.plot(df_mae_2019['투자일자'],df_chongja_2019['누적수익률(%)'],label="총자본증가율누적수익률")
plt.plot(df_mae_2019['투자일자'],df_i_2019['누적수익률(%)'],label="이자보상배율누적수익률")
plt.plot(df_mae_2019['투자일자'],df_be_2019['누적수익률(%)'],label="1주당매출액누적수익률")
plt.plot(df_mae_2019['투자일자'],df_soon_2019['누적수익률(%)'],label="순운전자본회전률누적수익률")
plt.plot(df_mae_2019['투자일자'],df_hyun_2019['누적수익률(%)'],label="현금비율누적수익률")
plt.plot(df_mae_2019['투자일자'],df_ja_2019['누적수익률(%)'],label="자기자본배율누적수익률")
plt.plot(df_mae_2019['투자일자'],df_mae_2019['누적수익률(%)'],label="비유동자산회전률누적수익률")
plt.plot(df_mae_2019['투자일자'],df_no_2019['누적수익률(%)'],label="노동소득분배율누적수익률")
plt.plot(df_mae_2019['투자일자'],df_mae_2019['코스닥연누적수익률(%)'],label="코스닥연누적수익률")
plt.legend(fontsize=16)
plt.xticks([0,249,495,741,984,1231,1478,1719,1960,2208,2452], rotation=45, fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(df_an_2019['투자일자'],df_soo_2019['누적수익률(%)'],label="수익성")
plt.plot(df_an_2019['투자일자'],df_chongja_2019['누적수익률(%)'],label="성장성")
plt.plot(df_an_2019['투자일자'],df_hwal_2019['누적수익률(%)'],label="활동성")
plt.plot(df_an_2019['투자일자'],df_an_2019['누적수익률(%)'],label="안정성")
plt.plot(df_an_2019['투자일자'],df_no_2019['누적수익률(%)'],label="생산성")
plt.plot(df_mae_2019['투자일자'],df_mae_2019['코스닥연누적수익률(%)'],label="코스닥연누적수익률")
plt.legend(fontsize=16)
plt.xticks([0,249,495,741,984,1231,1478,1719,1960,2208,2452], rotation=45, fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(df_an_2019['투자일자'],df_soo_2019['누적수익률(%)'],label="수익성")
plt.plot(df_an_2019['투자일자'],df_chongja_2019['누적수익률(%)'],label="성장성")
plt.plot(df_an_2019['투자일자'],df_hwal_2019['누적수익률(%)'],label="활동성")
plt.plot(df_an_2019['투자일자'],df_an_2019['누적수익률(%)'],label="안정성")
plt.plot(df_an_2019['투자일자'],df_bum_2019['누적수익률(%)'],label="범주혼합")
plt.plot(df_an_2019['투자일자'],df_mae_2019['코스닥연누적수익률(%)'],label="코스닥연누적수익률")
plt.legend(fontsize=16)
plt.xticks([0,249,495,741,984,1231,1478,1719,1960,2208,2452], rotation=45, fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(df_an_2019['투자일자'],df_to_2019['누적수익률(%)'],label="투자전략3")
plt.plot(df_an_2019['투자일자'],df_soo_2019['누적수익률(%)'],label="수익성")
plt.plot(df_an_2019['투자일자'],df_chongja_2019['누적수익률(%)'],label="성장성")
plt.plot(df_an_2019['투자일자'],df_hwal_2019['누적수익률(%)'],label="활동성")
plt.plot(df_an_2019['투자일자'],df_an_2019['누적수익률(%)'],label="안정성")
plt.plot(df_an_2019['투자일자'],df_bum_2019['누적수익률(%)'],label="범주혼합")
plt.plot(df_an_2019['투자일자'],df_mae_2019['코스닥연누적수익률(%)'],label="코스닥연누적수익률")
plt.legend(fontsize=16)
plt.xticks([0,249,495,741,984,1231,1478,1719,1960,2208,2452], rotation=45, fontsize=16)
plt.yticks(fontsize=16)
plt.show()
